# %%
import pandas as pd
df=pd.read_csv("Hindi_English_Truncated_Corpus.csv")
df
# Out:
#            source                                   english_sentence  \
# 0             ted  politicians do not have permission to do what ...
# 1             ted         I'd like to tell you about one such child,
# 2       indic2012  This percentage is even greater than the perce...
# 3             ted  what we really mean is that they're bad at not...
# 4       indic2012  .The ending portion of these Vedas is called U...
# ...           ...                                                ...
# 127602  indic2012  Examples of art deco construction can be found...
# 127603        ted                          and put it in our cheeks.
# 127604      tides  As for the other derivatives of sulphur , the ...
# 127605      tides  its complicated functioning is defined thus in...
# 127606        ted  They've just won four government contracts to ...
#
#                                            hindi_sentence
# 0       राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1       मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2        यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3          हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4             इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।
# ...                                                   ...
# 127602  आर्ट डेको शैली के निर्माण मैरीन ड्राइव और ओवल ...
# 127603                    और अपने गालों में डाल लेते हैं।
# 127604  जहां तक गंधक के अन्य उत्पादों का प्रश्न है , द...
# 127605  Zरचना-प्रकिया को उसने एक पहेली में यों बांधा है .
# 127606  हाल ही में उन्हें सरकारी ठेका मिला है करीब सौ ...
#
# [127607 rows x 3 columns]

# %%
df.drop(['source'], axis=1, inplace=True)

# %%
df
# Out:
#                                          english_sentence  \
# 0       politicians do not have permission to do what ...
# 1              I'd like to tell you about one such child,
# 2       This percentage is even greater than the perce...
# 3       what we really mean is that they're bad at not...
# 4       .The ending portion of these Vedas is called U...
# ...                                                   ...
# 127602  Examples of art deco construction can be found...
# 127603                          and put it in our cheeks.
# 127604  As for the other derivatives of sulphur , the ...
# 127605  its complicated functioning is defined thus in...
# 127606  They've just won four government contracts to ...
#
#                                            hindi_sentence
# 0       राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1       मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2        यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3          हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4             इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।
# ...                                                   ...
# 127602  आर्ट डेको शैली के निर्माण मैरीन ड्राइव और ओवल ...
# 127603                    और अपने गालों में डाल लेते हैं।
# 127604  जहां तक गंधक के अन्य उत्पादों का प्रश्न है , द...
# 127605  Zरचना-प्रकिया को उसने एक पहेली में यों बांधा है .
# 127606  हाल ही में उन्हें सरकारी ठेका मिला है करीब सौ ...
#
# [127607 rows x 2 columns]

# %%
pd.isnull(df).sum()
# Out:
# english_sentence    2
# hindi_sentence      0
# dtype: int64

# %%
df=df.dropna()

# %%
pd.isnull(df).sum()
# Out:
# english_sentence    0
# hindi_sentence      0
# dtype: int64

# %%
df['english_sentence'].value_counts()
# Out:
# (Laughter)                                                                                                                                                    555
# (Applause)                                                                                                                                                    373
# Thank you.                                                                                                                                                     98
# History                                                                                                                                                        59
# (Music)                                                                                                                                                        44
#                                                                                                                                                              ...
# But when it came to personal mattters it was a different story .                                                                                                1
# Layered and High-quality video                                                                                                                                  1
# In the year 1955 Mahadevi established the 'Sahityakar sansad' in Allahabad and along with P. Ilachandra Joshi undertook the responsibility of 'Sahityakar'      1
# The halved chromo- somes grow to full size , resulting in two cells ,                                                                                           1
# They've just won four government contracts to build off their 100 ambulances,                                                                                   1
# Name: english_sentence, Length: 124317, dtype: int64

# %%
#checking duplicate values
data=df
dupli=df[df.duplicated()]
data.drop_duplicates(inplace = True)
print("Duplicate Rows :")

print(dupli)
print(len(df))
# Out:
# Duplicate Rows :
#                 english_sentence         hindi_sentence
# 595            Internet in India        भारत मे अंतरजाल
# 652                   (Laughter)                (ठहाके)
# 992                   (Laughter)                 (हंसी)
# 1008                  (Laughter)                 (हँसी)
# 1135                  (Laughter)                 (हंसी)
# ...                          ...                    ...
# 127495                   Devotee                   भक्त
# 127516  Pashtun (Pathan) (15.4%)  पश्तून (पठान) (15.4%)
# 127519            Deputy Speaker               उपस्पीकर
# 127544                (Laughter)                 (हंसी)
# 127598                Thank you.              धन्यवाद |
#
# [2780 rows x 2 columns]
# 124825
# <ipython-input-8-71921670d79d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace = True)

# %%
dupli=df[df.duplicated()]
data.drop_duplicates(inplace = True)
print("Duplicate Rows :")
# Out:
# Duplicate Rows :
# <ipython-input-9-4ebbdb1f973e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace = True)

# %%
# checking duplicated data
isDuplicated = df.duplicated().any()
if isDuplicated:
    total_duplicates = df.duplicated().sum()
    print("Total duplicate rows are: ",total_duplicates)
    df.drop_duplicates(inplace = True)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokenizer.tokenize('Eighty-seven miles to go, yet.  Onward!')
# Out:
# ['Eighty', 'seven', 'miles', 'to', 'go', 'yet', 'Onward']

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
english_sentence=[]
for i in df["english_sentence"]:
  s=i.lower()
  print(tokenizer.tokenize(s))
# Out:
# Streaming output truncated to the last 5000 lines.
# ['the', 'terrible', 'spectacle', 'of', 'americanism', 'was', 'there', 'in', 'the', 'towering', 'flames', 'only', 'for', 'the', 'eyes', 'of', 'the', 'living']
# ['the', '63', 'year', 'old', 'poet', 'was', 'entering', 'the', 'evening', 'of', 'his', 'life', 'and', 'the', 'mellow', 'richness', 'of', 'the', 'evening', 'melody', 'pervades', 'these', 'poems']
# ['asian', 'horse', 'rider', 'position']
# ['tagore', 'particularly', 'wanted', 'that', 'there', 'should', 'be', 'more', 'constructive', 'activities', 'by', 'the', 'congress', 'so', 'that', 'ultimately', 'a', 'state', 'within', 'the', 'state', 'could', 'be', 'built', 'up', 'with', 'the', 'active', 'cooperation', 'and', 'support', 'of', 'the', 'people']
# ['it', 'was', 'later', 'alleged', 'that', 'her', 'dialogues', 'in', 'bengali', 'were', 'dubbed', 'by', 'tv', 'actress', 'reeta', 'kayral', 'and', 'had', 'not', 'even', 'been', 'acknowledged']
# ['here', 'is', 'the', 'story']
# ['workers', 'will', 'run', 'balco', 'if', 'chhattisgarh', 'is', 'allowed', 'to', 'buy', 'it']
# ['this', 'means', 'that', 'the', 'daughter', 'cell', 'would', 'have', 'an', 'exact', 'copy', 'of', 'the', 'genetic', 'material', 'the', 'dna', 'which', 'in', 'turn', 'means', 'that', 'the', 'sequence', 'of', 'the', 'bases', 'in', 'dna', 'of', 'a', 'daughter', 'cell', 'would', 'be', 'the', 'same', 'as', 'in', 'the', 'parent', 'cell']
# ['all', 'they', 'had']
# ['peace', 'with', 'this', 'group', 'is', 'imperative', 'because', 'this', 'is', 'the', 'strongest', 'militant', 'outfit', 'in', 'south', 'east', 'asia', 'after', 'the', 'liberation', 'tigers', 'of', 'tamil', 'eelam']
# ['effects', 'of', 'human', 'health']
# ['visitors', 'and', 'galleries', 'references', 'to', 'the', 'presence', 'of', 'strangers', 'in', 'the', 'visitors', 'gallery', 'have', 'been', 'held', 'to', 'be', 'out', 'of', 'order']
# ['how', 'rebellious', 'his', 'heart', 'was', 'growing', 'is', 'evident', 'from', 'the', 'stories', 'and', 'incidents', 'he', 'was', 'narrating', 'in', 'verse', 'which', 'were', 'published', 'in', 'the', 'same', 'year', 'as', 'palataka', 'lrb', 'the', 'fugitive', 'rrb']
# ['it', 'began', 'in', 'january', 'when', 'mumbai', 's', 'bull', 'operator', 'ketan', 'parekh', 'cornered', 'by', 'the', 'free', 'fall', 'in', 'the', 'prices', 'of', 'his', 'favoured', 'new', 'economy', 'stocks', 'shifted', 'a', 'chunk', 'of', 'his', 'holdings', 'in', 'hfcl', 'to', 'his', 'friends', 'in', 'kolkata']
# ['their', 'fear']
# ['so', 'bin', 'laden', 'is', 'scarier', 'because', 'he', 'has', 'a', 'name']
# ['the', 'ears', 'are', 'long']
# ['of', 'the', 'early', 'warning', 'score']
# ['the', 'amazing', 'egyptian']
# ['called', 'this', 'substitution']
# ['simple', 'machines', 'forum', 'ashtank', 'software', 'part', 'of', 'the', 'advertising', 'campaign', 'to', 'promote', 'hindi']
# ['with', 'an', 'annual', 'turnover', 'lrb', 'profit', 'margins', 'are', '2', '3', 'per', 'cent', 'of', 'turnover', 'rrb', 'between', 'rs', '4', '000', '6', '000', 'crore', 'martin', 'is', 'easily', 'the', 'most', 'powerful', 'man', 'in', 'the', 'game', 'today']
# ['these', 'animals', 'have', 'a', 'narrow', 'face', 'and', 'broad', 'forehead', 'which', 'is', 'slightly', 'dished']
# ['there', 'was', 'a', 'place', 'for', 'a', 'professor', 'of', 'international', 'health']
# ['the', 'entire', 'superstructure', 'is', 'of', 'brickwork']
# ['there', 'may', 'be', 'many', 'reasons']
# ['they', 'are', 'in', 'you', 'and', 'me', 'they', 'created', 'us', 'body', 'and', 'mind', 'and', 'their', 'preservation', 'is', 'the', 'ultimate', 'rationale', 'of', 'our', 'existence']
# ['nest', 'building', 'by', 'digging', 'crickets', 'many', 'beetles', 'and', 'other', 'insects', 'dig', 'their', 'brood', 'nests']
# ['1', 'the', 'national', 'minimum', 'wage', 'has', 'now', 'been', 'in', 'place', 'for', 'almost', 'two', 'years']
# ['but', 'certainly', 'not', 'b', 'c', 'or', 'd', 'right']
# ['having', 'been', 'virtually', 'dragged', 'into', 'politics', 'after', 'his', 'father', 'biju', 'patnaik', 's', 'death', 'the', 'chief', 'minister', 'knows', 'few', 'people', 'in', 'orissa', 'and', 'therefore', 'has', 'no', 'constraining', 'considerations']
# ['india', 'gave', 'refuge', 'to', 'the', 'jews', 'fleeing', 'the', 'destruction', 'of', 'the', 'first', 'temple']
# ['even', 'dolphins', 'are', 'found', 'in', 'sindhu', 'river']
# ['and', 'why', 'not']
# ['maulana', 'shah', 'abdul', 'haq', 'of', 'delhi', 'lrb', '1551', '1642', 'rrb', 'brought', 'indian', 'muslims', 'nearer', 'to', 'the', 'source', 'of', 'islamic', 'teaching', 'by', 'popularising', 'the', 'study', 'of', 'the', 'traditions', 'of', 'the', 'prophet']
# ['a', 'good', 'grain', 'ration', 'for', 'breeding', 'rams', 'can', 'be', 'prepared', 'by', 'mixing', 'two', 'parts', 'crushed', 'grain', 'or', 'guar', 'seed', 'one', 'part', 'wheat', 'bran', 'and', 'one', 'per', 'cent', 'salt']
# ['adding', 'to', 'the', 'pressure', 'was', 'a', 'note', 'from', 'the', 'rbi', 'to', 'banks', 'asking', 'them', 'to', 'pare', 'down', 'their', 'exposure', 'lrb', 'estimated', 'to', 'be', 'around', 'rs', '5', '000', 'crore', 'rrb', 'to', 'the', 'players', 'in', 'the', 'capital', 'market']
# ['how', 'common', 'are', 'temporomandibular', 'diseases', 'and', 'disorders']
# ['all', 'children', 'exhibit', 'the', 'same', 'evolution', 'in', 'visual', 'logic']
# ['since', 'then', 'the', 'practice', 'and', 'tradition', 'had', 'been', 'totally', 'given', 'up', 'or', 'forgotten', 'and', 'not', 'attempted', 'in', 'that', 'long', 'interval', 'of', 'rime', 'and', 'space']
# ['as', 'the', 'trial', 'proceeded', 'it', 'assumed', 'a', 'propagandist', 'character', 'on', 'both', 'sides']
# ['cambay', 'was', 'the', 'home', 'town', 'of', 'the', 'tyabji', 'family', 'the', 'nawab', 'was', 'a', 'personal', 'friend', 'and', 'in', 'his', 'time', 'of', 'acute', 'distress', 'it', 'seemed', 'obvious', 'that', 'it', 'was', 'the', 'duty', 'of', 'both', 'badruddin', 'and', 'his', 'brother', 'camruddin', 'to', 'do', 'their', 'best', 'for', 'him']
# ['convenience', 'to', 'man', 'giver', 'inconvenience', 'to', 'man', 'giver', 'joy', 'to', 'man', 'giver']
# ['the', 'incremental', 'advances', 'have', 'added', 'up', 'to', 'something']
# ['we', 'also', 'have', 'been', 'working', 'with', 'some', 'scientists']
# ['he', 'is', 'eternal', 'everywhere', 'and', 'existed', 'before', 'the', 'time']
# ['as', 'if', 'she', 'liked', 'the', 'crackers', 'and', 'didn', 't', 'like', 'the', 'broccoli']
# ['for', 'years', 'the', 'country', 'has', 'been', 'divided']
# ['be', 'aware', 'that', 'abnormal', 'cells', 'can', 'be', 'treated']
# ['a', 'survey', 'conducted', 'in', '1989', '90', 'indicated', 'that', 'about', '600', 'people', 'died', 'and', 'thousands', 'of', 'people', 'in', 'india', 'were', 'crippled', 'due', 'to', 'pesticide', 'poisoning']
# ['but', 'you', 'know']
# ['and', 'salmon', 'salad', 'sandwiches']
# ['the', 'judge', 'too', 'moved', 'as', 'if', 'to', 'rise', 'but', 'remembering', 'the', 'judicial', 'convention', 'kept', 'sitting']
# ['to', 'make', 'a', 'bank', 'loan']
# ['there', 'are', 'about', '400', 'tanneries', 'in', 'tamil', 'nadu', 'of', 'which', '260', 'units', 'are', 'located', 'in', 'the', 'north', 'arcot', 'district']
# ['here', 'the', 'inlay', 'work', 'is', 'not', 'petra', 'dura', 'rather', 'it', 'is', 'a', 'lapidary', 'artwork', 'of', 'precious', 'stones', 'and', 'gems']
# ['at', 'last', 'subhash', 'babu', 'understand', 'that', 'he', 'don', 't', 'get', 'any', 'thing', 'from', 'hitler', 'or', 'germany']
# ['parliament', '6', 'lesson']
# ['when', 'she', 'discovers']
# ['the', 'excise', 'duty', 'on', 'the', 'handloom', 'cloth', 'was', 'abolished', 'and', 'so', 'also', 'the', 'import', 'duty', 'and', 'excise', 'on', 'yarn']
# ['it', 'was', 'his', 'first', 'public', 'lecture', 'and', 'he', 'tried', 'to', 'prove', 'with', 'vocal', 'demonstrations', 'that', 'the', 'function', 'of', 'music', 'was', 'to', 'express', 'what', 'the', 'words', 'fail', 'to', 'express']
# ['other', 'forms', 'that', 'recur', 'in', 'statuary', 'are', 'those', 'of', 'shiva', 'and', 'his', 'wife', 'parvati', 'ganesh', 'vishnu', 'in', 'baikunth', 'uraa', 'mahesheshwar', 'mahishasur', 'mardini', 'lrb', 'durga', 'rrb', 'kartikeya', 'and', 'durga', 'as', 'shakti']
# ['the', 'velvety', 'brown', 'caterpillar', 'has', 'cream', 'coloured', 'cross', 'bancls', 'on', 'the', 'abdomen']
# ['to', 'travel', 'within', 'the', 'city', 'there', 'are', 'mumbai', 'suburban', 'trains', 'which', 'form', 'a', 'part', 'of', 'three', 'separate', 'network', 'whose', 'routes', 'run', 'from', 'north', 'to', 'south', 'direction']
# ['so', 'to', 'illustrate', 'that', 'question']
# ['since', 'i', 'live', 'on', 'a', 'houseboat', 'on', 'the', 'running', 'stream', 'of', 'lake', 'union']
# ['what', 'will', 'it', 'be', 'tomorrow']
# ['i', 'love', 'the', 'way', 'that', 'they', 'see', 'the', 'world']
# ['australia', 's', 'previous', 'trainer', 'john', 'b', 'kinyon', 'believes', 'that', 'short', 'balls', 'are', 'favorite', 'for', 'tendulkar', 'in', 'the', 'start', 'of', 'his', 'batting']
# ['the', 'law', 'makes', 'it', 'an', 'offence', 'to']
# ['that', 'birmingham', 'children', 's', 'hospital', 'were', 'already', 'running']
# ['sometimes', 'other', 'court', 'expenses', 'are', 'so', 'heavy', 'that', 'they', 'constrain', 'an', 'individual', 'litigant']
# ['which', 'documented', 'all', 'the', 'people']
# ['formation', 'of', 'local', 'court', 'in', 'order', 'to', 'save', 'money', 'and', 'time', 'as', 'per', 'request', 'of', 'lawers', 'of', 'court', 'and', 'for', 'benefit', 'of', 'people', 'requested', 'for', 'local', 'courts', 'but', 'due', 'to', 'following', 'reason', 'it', 'under', 'consideration']
# ['measure', 'joke']
# ['subashbabu', 'then', 'went', 'for', 'treatment', 'adalhaji']
# ['the', 'gajali', '1058', '1111', 'gives', 'some', 'argument', 'in', 'favor', 'of', 'sufi', 'mat', 'and', 'against', 'the', 'uselessness', 'of', 'philosophy', 'that', 'the', 'philosophy', 'started', 'weakens']
# ['according', 'to', 'counting', 'program', 'in', 'the', 'year', '2008', 'by', 'world', 'gadgettier', 'the', 'population', 'of', 'mumbai', 'was', '13', '662', '885']
# ['it', 'may', 'as', 'well', 'be', 'considered', 'to', 'be', 'the', 'precursor', 'of', 'or', 'the', 'model', 'for', 'the', 'exquisitely', 'designed', 'and', 'ornately', 'carved', 'subrahmanya', 'temple', 'unit', 'of', 'nayaka', 'times', 'inside', 'the', 'enclosure', 'of', 'the', 'thanjavur', 'brihadisvara', 'temple', 'complex']
# ['this', 'mission', 'was', 'repeatedly', 'delayed', 'due', 'to', 'scheduling', 'conflicts', 'and', 'technical', 'problems', 'such', 'as', 'the', 'discovery', 'of', 'cracks', 'in', 'the', 'shuttle', 'engine', 'flow', 'liners']
# ['so', 'they', 'wait', 'until', 'winter']
# ['one', 'among', 'the', 'eight', 'areas', 'of', 'unesco', 'is', 'kadmandu', 's', 'oldest', 'temples', 'palaces', 'and', 'streets']
# ['he', 'welcomed', 'the', 'emergence', 'of', 'this', 'left', 'wing', 'current', 'in', 'indian', 'politics', 'because', 'he', 'was', 'of', 'the', 'opinion', 'that', 'the', 'instinct', 'that', 'had', 'led', 'to', 'its', 'formation', 'was', 'historically', 'correct']
# ['class', 'journalism']
# ['as', 'the', 'akbar', 'becomes', 'older', 'his', 'interest', 'towards', 'religion', 'starts', 'increasing']
# ['with', 'unique', 'devotion', 'glory', 'of', 'faith', 'to', 'the', 'body', 'of', 'his', 'teacher', 'who', 'is', 'a', 'ideal', 'and', 'a', 'godliness', 'deserves', 'to', 'be', 'served']
# ['and', 'everything', 'else', 'sort', 'of', 'goes', 'dark']
# ['were', 'inspired', 'as', 'young', 'children', 'this', 'little', 'three', 'to', '15', 'year', 'old', 'age']
# ['i', 'am', 'addressing', 'this', 'letter', 'to', 'some', 'friends', 'who', 'are', 'not', 'connected', 'with', 'the', 'congress', 'organisation', 'and', 'i', 'trust', 'that', 'it', 'will', 'be', 'possible', 'to', 'build', 'up', 'with', 'their', 'help', 'and', 'cooperation', 'a', 'non', 'party', 'and', 'non', 'sectarian', 'union', 'of', 'the', 'kind', 'i', 'have', 'outlined', 'above']
# ['in', '1944', 'while', 'talking', 'to', 'american', 'journalist', 'louis', 'fischer', 'gabdhiji', 'referred', 'netaji', 'as', 'patriot', 'among', 'patriots']
# ['i', 'think', 'that', 'it', 's', 'important', 'for', 'us', 'to', 'remember']
# ['dia', 's', 'director', 'is', 'a', 'three', 'star', 'military', 'officer', 'who', 'serves', 'as', 'principal', 'adviser', 'to', 'the', 'secretary', 'of', 'defense', 'and', 'to', 'the', 'chairman', 'of', 'the', 'joint', 'chiefs', 'of', 'staff', 'on', 'matters', 'of', 'military', 'intelligence', 'the', 'director', 'also', 'chairs', 'the', 'military', 'intelligence', 'board', 'which', 'coordinates', 'activities', 'of', 'the', 'defense', 'intelligence', 'community', '2', 'the', 'exact', 'numbers', 'and', 'specific', 'budget', 'information', 'are', 'not', 'publicly', 'released', 'due', 'to', 'security', 'considerations', 'dia', 'has', 'major', 'operational', 'activities', 'at', 'the', 'pentagon', 'the', 'defense', 'intelligence', 'analysis', 'center', 'diac', 'bolling', 'air', 'force', 'base', 'in', 'washington', 'd', 'c', '38', '848', 'n', '77', '012', 'w', 'the', 'national', 'center', 'for', 'medical', 'intelligence', 'ncmi', 'in', 'fort', 'detrick', 'maryland', 'and', 'the', 'missile', 'and', 'space', 'intelligence', 'center', 'msic', 'in', 'huntsville', 'alabama', 'dia', 'is', 'a', 'member', 'of', 'the', 'united', 'states', 'intelligence', 'community', 'reporting', 'to', 'the', 'director', 'of', 'national', 'intelligence', 'dia', 'possesses', 'a', 'diverse', 'workforce', 'skilled', 'in', 'the', 'areas', 'of', 'military', 'history', 'and', 'doctrine', 'economics', 'physics', 'chemistry', 'world', 'history', 'political', 'science', 'bio', 'sciences', 'computer', 'sciences', 'and', 'many', 'other', 'fields', 'of', 'expertise', 'the', 'agency', 'responds', 'to', 'the', 'needs', 'of', 'a', 'variety', 'of', 'customers', 'from', 'the', 'president', 'of', 'the', 'united', 'states', 'to', 'the', 'soldier', 'in', 'the', 'field', 'its', 'work', 'encompasses', 'all', 'aspects', 'of', 'military', 'intelligence', 'requirements', 'from', 'highly', 'complex', 'missile', 'trajectory', 'data', 'to', 'biographical', 'information', 'on', 'foreign', 'military', 'leaders']
# ['more', 'and', 'more', 'information', 'is', 'available', 'to', 'the', 'public', 'about', 'their', 'local', 'health', 'services', 'for', 'example', 'through', 'the', 'hospital', 'league', 'tables']
# ['in', 'the', 'corner', 'of', 'a', 'dark', 'room']
# ['whole', 'responsibility', 'lies', 'with', 'the', 'male', 'to', 'push', 'while', 'having', 'sex', 'this', 'is', 'old', 'but', 'evergreen', 'position', 'for', 'any', 'position', 'discussion', 'should', 'be', 'having', 'with', 'the', 'partner', 'for', 'new', 'entry', 'this', 'is', 'the', 'best', 'position', 'they', 'need', 'to', 'maintain', 'the', 'flow', 'to', 'enjoy', 'the', 'sex', 'in', 'this', 'position']
# ['the', 'villagers', 'say', 'basava', 'basava', 'whenever', 'there', 'is', 'a', 'calamity', 'or', 'a', 'danger', 'with', 'the', 'hope', 'that', 'it', 'will', 'be', 'averted']
# ['it', 'was', 'a', 'matter', 'which', 'could', 'not', 'have', 'been', 'raised', 'under', 'any', 'other', 'rule']
# ['of', 'scores', 'which', 'go', 'up', 'with', 'time']
# ['and', 'call', 'them', 'out', 'and', 'find', 'out', 'what', 'those', 'techniques', 'are']
# ['the', 'freedom', 'that', 'we', 'envisage', 'is', 'not', 'to', 'be', 'confined', 'to', 'this', 'nation', 'or', 'that', 'or', 'to', 'a', 'particular', 'people', 'but', 'must', 'spread', 'out', 'over', 'the', 'whole', 'human', 'race']
# ['both', 'as', 'aquatic', 'larvae', 'and', 'as', 'aerial', 'adult', 'these', 'insects', 'are', 'voracious', 'hunt', 'ers']
# ['due', 'to', 'some', 'arguements', 'on', 'the', 'issue', 'of', 'inheritence', 'of', 'islam', 'shah', 'son', 'of', 'shershah', 'suri', 'humayun', 'again', 'took', 'the', 'control', 'of', 'delhi', 'in', 'the', 'year', '1555']
# ['the', 'first', 'commercial', 'deployment', 'of', 'a', 'short', 'message', 'service', 'center', 'smsc', 'was', 'by', 'aldiscon', 'now', 'acision', 'with', 'telia', 'now', 'teliasonera', 'in', 'sweden', 'in', '1993', '21', 'followed', 'by', 'fleet', 'call', 'now', 'nextel', 'citation', 'needed', 'in', 'the', 'us', 'telenor', 'in', 'norway', 'citation', 'needed', 'and', 'bt', 'cellnet', 'now', 'o2', 'uk', 'citation', 'needed', 'later', 'in', '1993', 'all', 'first', 'installations', 'of', 'sms', 'gateways', 'were', 'for', 'network', 'notifications', 'sent', 'to', 'mobile', 'phones', 'usually', 'to', 'inform', 'of', 'voice', 'mail', 'messages', 'the', 'first', 'commercially', 'sold', 'sms', 'service', 'was', 'offered', 'to', 'consumers', 'as', 'a', 'person', 'to', 'person', 'text', 'messaging', 'service', 'by', 'radiolinja', 'now', 'part', 'of', 'elisa', 'in', 'finland', 'in', '1993', 'it', 'should', 'be', 'noted', 'that', 'most', 'early', 'gsm', 'mobile', 'phone', 'handsets', 'did', 'not', 'support', 'the', 'ability', 'to', 'send', 'sms', 'text', 'messages', 'and', 'nokia', 'was', 'the', 'only', 'handset', 'manufacturer', 'whose', 'total', 'gsm', 'phone', 'line', 'in', '1993', 'supported', 'user', 'sending', 'of', 'sms', 'text', 'messages', 'initial', 'growth', 'was', 'slow', 'with', 'customers', 'in', '1995', 'sending', 'on', 'average', 'only', '0', '4', 'messages', 'per', 'gsm', 'customer', 'per', 'month', '22', 'one', 'factor', 'in', 'the', 'slow', 'takeup', 'of', 'sms', 'was', 'that', 'operators', 'were', 'slow', 'to', 'set', 'up', 'charging', 'systems', 'especially', 'for', 'prepaid', 'subscribers', 'and', 'eliminate', 'billing', 'fraud', 'which', 'was', 'possible', 'by', 'changing', 'smsc', 'settings', 'on', 'individual', 'handsets', 'to', 'use', 'the', 'smscs', 'of', 'other', 'operators']
# ['the', 'modern', 'medical', 'practitioners', 'have', 'had', 'no', 'clue', 'as', 'to', 'the', 'rationale', 'of', 'such', 'claims', 'nor', 'could', 'they', 'scientifically', 'corroborate', 'validity', 'of', 'the', 'beneficial', 'effects', 'of', 'such', 'methods', 'of', 'alleviating', 'diabetes']
# ['he', 'said', 'that', 'parliamentary', 'democracy', 'was', 'meaningless', 'unless', 'it', 'was', 'geared', 'to', 'achieving', 'the', 'real', 'goal', 'of', 'economic', 'democracy']
# ['however', 'a', 'motion', 'under', 'rule', '342', 'that', 'a', 'policy', 'or', 'situation', 'or', 'statement', 'or', 'any', 'other', 'matter', 'be', 'taken', 'into', 'consideration', 'is', 'not', 'put', 'to', 'vote']
# ['its', 'place', 'was', 'primarily', 'on', 'the', 'banks', 'of', 'the', 'indus', 'river', 'though', 'one', 'can', 'see', 'remains', 'of', 'this', 'is', 'gujarat', 'india', 'and', 'rajasthan']
# ['tow', 'children', 'born', 'to', 'the', 'cople', 'namesd', 'sweta', 'daughter', 'and', 'son', 'abhisekh']
# ['so', 'the', 'one', 'on', 'the', 'top']
# ['if', 'we', 'get', 'the', 'god', 'by', 'worshiping', 'i', 'will', 'worship']
# ['but', 'did', 'the', 'regime', 'learn', 'anything', 'not', 'really']
# ['because', 'it', 'will', 'no', 'longer', 'be', 'possible', 'to', 'believe', 'that', 'aging', 'is', 'inevitable', 'in', 'humans']
# ['thus', 'it', 'is', 'also', 'clear', 'that', 'apart', 'from', 'the', 'physiological', 'functions', 'mentioned', 'in', 'the', 'above', 'definition', 'certain', 'morphological', 'features', 'are', 'also', 'known', 'to', 'take', 'place', 'with', 'age']
# ['he', 'regretted', 'later', 'that', 'he', 'ever', 'wrote', 'them']
# ['the', 'names', 'of', 'local', 'solicitors', 'who', 'have', 'experience', 'in', 'landlord', 'and', 'tenant', 'law', 'may', 'be', 'available', 'from', 'the', 'citizens', 'advice', 'bureau', 'or', 'other', 'independent', 'advice', 'agencies']
# ['hindustan']
# ['abu', 'zafar', 'son', 'of', 'king', 'akbar', 'ii', 'of', 'delhi', 'was', 'the', 'last', 'ruler', 'of', 'the', 'mughal', 'dynasty', 'founded', 'by', 'babur', 'in', '1526']
# ['the', 'pew', 'center', 'is', 'known', 'for', 'keeping', 'an', 'eye', 'over', 'the', 'environmental', 'changes', 'all', 'over', 'the', 'world']
# ['we', 'are', 'losing', 'our', 'listening']
# ['the', 'qualities', 'of', 'these', 'beings', 'are', 'different', 'inasmuch', 'as', 'they', 'have', 'attained', 'this', 'stage', 'of', 'life', 'in', 'the', 'course', 'of', 'metempsychosis', 'by', 'action', 'and', 'actions', 'are', 'different', 'on', 'account', 'of', 'the', 'three', 'primary', 'forces', 'they', 'live', 'very', 'long', 'since', 'they', 'have', 'entirely', 'stripped', 'off', 'the', 'bodies', 'since', 'they', 'are', 'free', 'from', 'all', 'exertion', 'and', 'are', 'able', 'to', 'do', 'things', 'which', 'are', 'impossible', 'to', 'man']
# ['for', 'the', 'farmer', 'must', 'buy', 'new', 'hybrid', 'seed', 'each', 'year', 'from', 'a', 'specialised', 'seed', 'producer']
# ['romani', 'language', 'of', 'european', 'gypsies', 'is', 'also', 'included', 'in', 'these', 'languages']
# ['abhilekh', 'court']
# ['swine', 'fever', 'is', 'a', 'highly', 'contagious', 'disease']
# ['marathi', 'literature', 'is', 'also', 'became', 'modern', 'as', 'per', 'the', 'time', 'course']
# ['so', 'you', 'would', 'not', 'confuse', 'it', 'with', 'advertising']
# ['any', 'word', 'or', 'portions', 'ordered', 'not', 'to', 'be', 'recorded', 'or', 'expunged', 'from', 'the', 'proceedings', 'as', 'being', 'unparliamentary', 'cannot', 'be', 'published', 'by', 'the', 'media', 'or', 'anyone', 'else', 'as', 'there', 'is', 'no', 'unlimited', 'right', 'to', 'the', 'publication', 'of', 'the', 'proceedings', 'of', 'the', 'houses', 'of', 'parliament']
# ['leg', 'bye', 'extra', 'given', 'run', 'when', 'ball', 'hit', 'the', 'batsman', 'body', 'not', 'bat', 'and', 'this', 'goes', 'away', 'form', 'the', 'filders', 'allow', 'the', 'batsman', 'to', 'time', 'take', 'runs', 'as', 'normally', 'he', 'takes']
# ['what', 'happens', 'when', 'a', 'number', 'of', 'genes', 'concerned', 'with', 'the', 'programme', 'of', 'aging', 'are', 'inherited', 'in', 'an', 'altered', 'form']
# ['the', 'conclusion', 'to', 'which', 'this', 'discussion', 'leads', 'us', 'is', 'this', 'people', 'living', 'in', 'a', 'compact', 'geographical', 'area', 'with', 'a', 'general', 'cultural', 'unity', 'have', 'a', 'minimum', 'requisite', 'for', 'nationhood', 'and', 'can', 'become', 'a', 'nation', 'by', 'accepting', 'a', 'particular', 'political', 'order', 'and', 'forming', 'a', 'state']
# ['actually', 'you', 'can', 'also', 'change', 'the', 'frequency', 'of', 'the', 'air', 'coming', 'out']
# ['it', 'becomes', 'incredibly', 'important']
# ['yeah', 'well']
# ['and', '1298', 'ambulances', 'decided', 'that', 'it', 'was', 'going', 'to']
# ['the', 'tata', 'hydro', 'electric', 'supply', 'company', 'ltd', 'was', 'founded', 'in', '1910', 'with', 'the', 'purpose', 'of', 'utilising', 'monsoon', 'waters', 'of', 'the', 'western', 'ghats', 'and', 'for', 'generating', '30', '000', 'hp', 'with', 'a', 'capital', 'of', 'rs', '1', '75', 'crores']
# ['and', 'that', 'makes', 'us', 'larger', 'than', 'the', 'u', 's', 'as', 'a', 'telephone', 'market']
# ['there', 's', 'stories', 'that', 'you', 'may', 'tell']
# ['varahamihira', 'has', 'composed', 'an', 'astronomical', 'handbook', 'of', 'small', 'compass', 'called', 'panca', 'siddhantika', 'which', 'name', 'ought', 'to', 'mean', 'that', 'it', 'contains', 'the', 'pith', 'and', 'marrow', 'of', 'the', 'preceding', 'five', 'siddhantas']
# ['and', 'actually', 'put', 'them', 'to', 'use']
# ['as', 'per', 'request', 'of', 'members', 'indian', 'govt', 'has', 'to', 'pay', 'the', 'amount', 'including', 'the', 'interest']
# ['and', 'so', 'the', 'ghat', 'speaks', 'lrb', 'the', 'story', 'called', 'ghater', 'katha', 'rrb', 'and', 'recalls', 'how', 'a', 'charming', 'little', 'girl', 'once', 'used', 'to', 'come', 'to', 'the', 'river', 'so', 'sweet', 'she', 'seemed', 'that', 'when', 'her', 'shadow', 'fell', 'on', 'the', 'water', 'i', 'used', 'to', 'wish', 'if', 'i', 'could', 'only', 'catch', 'that', 'shadow', 'and', 'keep', 'it', 'clasped', 'to', 'my', 'stones']
# ['skuspey', 'using', 'the', 'internet', 'to', 'use', 'them', 'in', 'any', 'dechste', 'boxes', 'can', 'hinatie', 'uses']
# ['when', 'the', 'accused', 'person', 'is', 'brought', 'before', 'the', 'court', 'in', 'a', 'warrant', 'case', 'the', 'magistrate', 'does', 'not', 'question', 'him', 'till', 'at', 'least', 'some', 'of', 'the', 'prosecution', 'evidence', 'has', 'been', 'heard']
# ['in', 'rural', 'areas', 'pockets', 'of', 'deprivation', 'can', 'be', 'hidden', 'by', 'ward', 'level', 'statistics']
# ['and', 'some', 'of', 'you', 'all', 'might', 'know']
# ['they', 'need', 'much', 'more', 'than', 'anything', 'else']
# ['boy', 'oh', 'because', 'the', 'light', 'goes', 'only', 'to', 'here']
# ['any', 'attempt', 'to', 'discuss', 'these', 'principles', 'in', 'the', 'abstract', 'was', 'bound', 'to', 'lead', 'to', 'fundamental', 'differences', 'of', 'approach', 'at', 'the', 'outset', 'and', 'possibly', 'to', 'a', 'splitting', 'up', 'of', 'the', 'committee']
# ['at', 'times', 'to', 'make', 'his', 'point', 'clear', 'he', 'spoke', 'in', 'parables']
# ['his', 'efforts', 'have', 'been', 'in', 'vain', 'so', 'far', 'but', 'bains', 'has', 'not', 'returned']
# ['if', 'you', 'find', 'out', 'your', 'child', 'is', 'using', 'drugs', 'or', 'solvents', 'stay', 'calm', 'and', 'do', 'n', 't', 'panic']
# ['the', 'master', 'organ', 'the', 'brain', 'loses', '20', 'per', 'cent', 'of', 'its', 'weight', 'from', 'adulthood', 'to', 'old', 'age']
# ['that', 's', 'how', 'at', '17', 'years', 'old']
# ['all', 'those', 'work', 'under', 'the', 'guise', 'of', 'spammers']
# ['the', 'usage', 'of', 'client', 'and', 'desktop', 'are', 'mostly', 'used', 'in', 'the', 'computer', 'language']
# ['most', 'of', 'the', 'kerala', 'temples', 'now', 'existing', 'are', 'not', 'very', 'old', 'the', 'oldest', 'dating', 'from', 'medieval', 'or', 'post', 'medieval', 'times']
# ['for', 'instance', 'the', 'tamboora', 'is', 'invariably', 'connected', 'with', 'the', 'sages', 'tumburu', 'and', 'narada', 'both', 'mythological', 'character', 'and', 'even', 'if', 'they', 'were', 'historical', 'figures', 'nothing', 'of', 'their', 'history', 'is', 'known']
# ['so', 'i', 'said', 'great', 'so', 'i', 'called', 'him', 'up', 'a', 'few', 'weeks', 'afterward']
# ['how', 'teaching', 'english']
# ['i', 'am', 'not', 'optimist', 'enough', 'to', 'imagine', 'that', 'out', 'of', 'this', 'chaos', 'a', 'free', 'united', 'and', 'advanced', 'india', 'will', 'emerge']
# ['they', 'got', 'the', 'aga', 'khan', 'award', 'for', 'architecture', 'in', '2002']
# ['they', 'could', 'not', 'take', 'any', 'more', 'of', 'this']
# ['in', 'mumbai', 'bcci', 'board', 'of', 'control', 'for', 'cricket', 'in', 'india', 'is', 'situated']
# ['in', 'winter', 'when', 'there', 'is', 'snow', 'falls', 'the', 'water', 'level', 'in', 'the', 'river', 'rises', 'floods', 'well', 'this', 'time', 'mud', 'of', 'refting', 'kyaking', 'and', 'canoing', 'are', 'organised', 'on', 'the', 'leader', 'badrinath', 'route', 'which', 'attract', 'tourists', 'and', 'lovers', 'having', 'interest', 'in', 'courageous', 'games', 'which', 'plays', 'an', 'important', 'role', 'in', 'the', 'financial', 'support', 'of', 'india']
# ['it', 'is', 'a', 'very', 'desirable', 'practice', 'especially', 'when', 'the', 'winter', 'coat', 'is', 'heavy']
# ['she', 'told', 'me', 'this', 'she', 'said', 'i', 'walked', 'out', 'of', 'auschwitz', 'into', 'life']
# ['mumbai', 'government', 'law', 'college', 'and', 'cdenhem', 'college', 'are', 'ancient', 'universities', 'of', 'mumbai']
# ['the', 'fog', 'and', 'rain']
# ['road', 'safety', 'at', 'school']
# ['and', 'they', 'come', 'up', 'one', 'at', 'a', 'time']
# ['in', 'winter', 'as', 'he', 'put', 'it', 'lyrical', 'fervour', 'is', 'apt', 'to', 'grow', 'cold', 'and', 'one', 'gets', 'the', 'leisure', 'to', 'write', 'drama']
# ['article', '263', 'is', 'to', 'empower', 'president', 'that', 'inter', 'state', 'council', 'shall', 'set', 'up', 'so', 'that', 'to', 'resolve', 'differences', 'do', 'arise', 'between', 'states']
# ['later', 'they', 'established', 'their', 'rule', 'over', 'the', 'greater', 'part', 'of', 'upper', 'sind']
# ['karna', 'son', 'of', 'suryadev', 'and', 'kunti']
# ['employed', '39', '9']
# ['and', 'why', 'should', 'we', 'care', 'about', 'this']
# ['he', 'only', 'says', 'we', 'can', 't', 'do', 'it']
# ['he', 'interdicted', 'the', 'hindus', 'from', 'considering', 'and', 'representing', 'themselves', 'as', 'anything', 'but', 'sakas']
# ['ayodhya', 'is', 'left', 'out', 'on', 'the', 'excuse', 'that', 'the', 'matter', 'is', 'in', 'the', 'courts']
# ['your', 'landlord', 'cannot', 'evict', 'you', 'without', 'a', 'possession', 'order', 'from', 'the', 'court']
# ['but', 'half', 'the', 'time', 'we', 'would', 'pick', 'it', 'up']
# ['in', 'the', 'year', '1971', 'he', 'was', 'given', 'the', 'best', 'actor', 'award', 'for', 'the', 'movie', 'kaala', 'patthar', 'then', 'in', '1980', 'again', 'he', 'was', 'given', 'award', 'for', 'the', 'movie', 'named', 'dostana', 'with', 'co', 'stars', 'shatrughun', 'sinha', 'and', 'zeenat', 'aman']
# ['i', 'can', 'feel', 'it', 'we', 'want', 'to', 'hear', 'a', 'little', 'more']
# ['she', 'became', 'close', 'friends', 'with', 'subadhra', 'kumari', 'chauhan', 'in', 'college']
# ['and', 'he', 'controls', 'them', 'from', 'the', 'top', 'down']
# ['so', 'it', 'may', 'be', 'that', 'the', 'neural', 'mechanisms']
# ['according', 'muslims', 'god', 'is', 'unique', 'there', 'is', 'nobody', 'else', 'like', 'him']
# ['his', 'ominous', 'tone', 'echoed', 'pakistani', 'concerns', 'about', 'the', 'lack', 'of', 'representation', 'of', 'the', 'majority', 'pashtoon', 'community', 'within', 'the', 'northern', 'alliance']
# ['the', 'delay', 'in', 'reaching', 'balance', 'is', 'due', 'to', 'the', 'vast', 'temperature', 'change', 'of', 'oceans']
# ['so', 'music', 'videos', 'are', 'something', 'that', 'i', 'always', 'found', 'interesting']
# ['on', 'this', 'day', 'people', 'decorate', 'their', 'cows', 'and', 'bulls', 'and', 'orrer', 'prayers', 'to', 'mound', 'of', 'cow', 'dung']
# ['in', 'calcutta', 'deshbandhu', 'launched', 'his', 'english', 'daily', 'paper', 'forward', 'after', 'the', 'delhi', 'congress', 'and', 'entrusted', 'subhas', 'with', 'its', 'organisation']
# ['so', 'what', 'we', 'discovered']
# ['then', 'sri', 'krishna', 'reminds', 'arjuna', 'of', 'his', 'killing', 'of', 'abhimanyu', 'his', 'calling', 'draupadi', 'a', 'prostitute', 'in', 'kuru', 'assembly', 'and', 'asks', 'him', 'to', 'kill', 'karan', 'by', 'reminding', 'of', 'him', 'of', 'his', 'pledge', 'to', 'kill', 'karan', 'then', 'arjuna', 'seperated', 'karan', 's', 'head', 'by', 'his', 'torso', 'by', 'a', 'divine', 'weapon']
# ['harsha', 'bhogle', 'suddenly', 'india', 'discovered', 'this', 'power', 'of', '20', 'overs', 'cricket']
# ['next', 'challenge']
# ['industry', 'or', 'vehicles', 'problems', 'pollution', 'problems', 'can', 'be', 'written', 'like', 'this', 'they', 'must', 'stop', 'pollution', 'or', 'this', 'can', 'be', 'changed', 'as', 'a', 'modified', 'stream']
# ['what', 'is', 'dr', 'smith', 's', 'address']
# ['towards', 'a', 'renaissance', 'in', 'africa']
# ['very', 'often', 'the', 'mother', 'herself', 'prepares', 'the', 'necessary', 'food', 'or', 'cultivates', 'and', 'stores', 'up', 'in', 'the', 'nest', 'the', 'special', 'food', 'plant', 'on', 'which', 'the', 'larva', 'will', 'feed']
# ['who', 'the', 'next', 'president', 'of', 'america', 'would', 'be', 'now', 'depends', 'on', 'the', '3', '000', 'odd', 'votes', 'posted', 'by', 'us', 'armed', 'forces', 'personnel', 'on', 'missions', 'in', 'places', 'like', 'kosovo']
# ['his', 'did', 'put', 'footwear', 'of', 'ram', 'at', 'administration', 'pulpit', 'and', 'being', 'start', 'live', 'in', 'nandigram']
# ['king', 'was', 'limited', 'to', 'their', 'names', 'and', 'prime', 'minister', 'post', 'were', 'made', 'powerful']
# ['there', 'are', 'about', '120', 'you', 'see', 'them', 'here']
# ['you', 'can', 'stand', 'on', 'one', 'side', 'of', 'the', 'world']
# ['in', 'islam', 'emphasis', 'is', 'laid', 'on', 'hi', 'formless', 'form']
# ['other', 'than', 'these', 'sunder', 'ban', 'contains', 'species', 'of', 'deva', 'kewda', 'tarmaja', 'and', 'goran', 'trees']
# ['it', 'is', 'n', 't', 'a', 'good', 'idea', 'to', 'focus', 'too', 'much', 'on', 'the', 'use', 'of', 'drugs', 'but', 'rather', 'on', 'the', 'other', 'problems', 'and', 'difficulties', 'that', 'the', 'young', 'person', 'has']
# ['member', 'of', 'raj', 'ya', 'sabha', 'can', 'be', 'minister', 'where', 'he', 'can', 'take', 'decision', 'on', 'cabinet', 'level']
# ['the', 'most', 'remarkable', 'aspect', 'of', 'his', 'deepening', 'religious', 'insight', 'was', 'that', 'it', 'enriched', 'instead', 'of', 'eating', 'into', 'or', 'warping', 'his', 'love', 'of', 'this', 'earth', 'and', 'this', 'life']
# ['dainik', 'jagran', 'e', 'paper']
# ['but', 'how', 'much', 'of', 'it', 'was', 'due', 'to', 'inheritance', 'from', 'both', 'parents', 'and', 'how', 'much', 'due', 'to', 'the', 'home', 'the', 'educational', 'environment', 'opportunity', 'to', 'excel', 'and', 'the', 'tradition', 'of', 'the', 'class', 'is', 'as', 'yet', 'anyone', 's', 'guess']
# ['it', 'is', 'also', 'called', 'furkan', 'kasauti', 'al', 'hikm', 'wisdom', 'dhikra', 'memory', 'and', 'mashhaf', 'written']
# ['unsung', 'heroes', 'shooter', 'abhinav', 'bindra', 'with', 'his', 'junior', 'world', 'record', 'and', 'senior', 'world', 'cup', 'medal', 'and', 'badminton', 'player', 'abhinn', 'shyam', 'gupta', 'who', 'won', 'the', 'french', 'open', 'title']
# ['sanskrit', 'language', 'biseshtc']
# ['and', 'the', 'cycle', 'continues']
# ['before', 'his', 'death', 'akbar', 'in', 'the', 'year', '1599', 'again', 'made', 'the', 'agra', 'as', 'capital', 'and', 'handled', 'the', 'rule', 'here', 'only', 'till', 'the', 'end']
# ['far', 'west', 'mountain', 'university']
# ['then', 'he', 'was', 'elected', 'as', 'mayor', 'of', 'calcutta']
# ['and', 'are', 'now', 'beginning', 'to', 'scale', 'because', 'of', 'partnership']
# ['we', 'decided', 'to', 'take', 'the', 'next', 'big', 'step']
# ['the', 'ter', 'temple', 'now', 'containing', 'a', 'trivikrama', 'image', 'shows', 'more', 'advanced', 'features']
# ['i', 'was', 'compassionate', 'i', 'was', 'very', 'sensitive', 'to', 'injustice']
# ['excuse', 'me', 'who', 'built', 'these', 'structures']
# ['the', 'source', 'of', 'such', 'an', 'enormous', 'increase', 'in', 'mass', 'is', 'evidently', 'the', 'food', 'that', 'the', 'organism', 'continually', 'extracts', 'from', 'the', 'external', 'environment', 'for', 'its', 'own', 'buildup']
# ['without', 'directly', 'referring', 'to', 'the', 'mahatma', 'or', 'criticising', 'his', 'leadership', 'tagore', 'gave', 'eloquent', 'expression', 'to', 'his', 'faith', 'in', 'the', 'necessity', 'of', 'intellectual', 'and', 'moral', 'cooperation', 'between', 'india', 'and', 'the', 'west', 'in', 'a', 'public', 'lecture', 'in', 'calcutta', 'entitled', 'siksharmilan', 'lrb', 'meeting', 'of', 'cultures', 'rrb']
# ['started', 'working', '1969', '1972']
# ['in', 'a', 'magnificent', 'and', 'statesmanlike', 'gesture', 'rash', 'behari', 'bose', 'handed', 'over', 'the', 'leadership', 'of', 'the', 'entire', 'movement', 'to', 'netaji']
# ['and', 'decrease', 'the', 'speed', 'of', 'rotor', 'one']
# ['yajnavalkya', 'provides', 'that', 'the', 'king', 'may', 'review', 'and', 'set', 'aside', 'a', 'decision', 'which', 'has', 'been', 'wrongly', 'given', 'even', 'by', 'him', 'he', 'could', 'also', 'award', 'costs']
# ['the', 'sector', 'wise', 'targets', 'are', 'indicated', 'in', 'table', '12', '2']
# ['but', 'when', 'it', 'comes', 'to', 'our', 'poor', 'brethren']
# ['subsequently', 'a', 'stage', 'came', 'when', 'a', 'simple', 'maha', 'mandapa', 'was', 'added', 'in', 'front', 'of', 'the', 'ardha', 'mandapa', 'and', 'was', 'well', 'integrated', 'with', 'the', 'main', 'parts', 'the', 'whole', 'often', 'surrounded', 'by', 'an', 'enclosure', 'wall', 'the', 'prakara']
# ['a', 'few', 'artificial', 'sweetners', 'without', 'caloric', 'value', 'are', 'also', 'available']
# ['human', 'activity', 'increased', 'after', 'the', 'industrial', 'revolution', 'due', 'to', 'which', 'the', 'quantity', 'of', 'greenhouse', 'gases', 'has', 'greatly', 'increased', 'as', 'a', 'result', 'radiative', 'forcing', 'co2', 'methane', 'tropospheric', 'ozone', 'cfcs', 'and', 'nitrous', 'oxide', 'have', 'also', 'greatly', 'increased', 'at', 'the', 'level', 'of', 'the', 'molecule', 'methane', 'greenhouse', 'gas', 'is', 'more', 'potent', 'than', 'carbon', 'dioxide', 'but', 'its', 'concentration', 'is', 'low', 'that', 'its', 'radiative', 'forcing', 'is', 'one', 'fourth', 'that', 'of', 'carbon', 'dioxide', 'some', 'other', 'naturally', 'emitted', 'gases', 'contribute', 'to', 'the', 'greenhouse', 'effect']
# ['to', 'find', 'out', 'more', 'about', 'disabled', 'person', 's', 'tax', 'credit', 'phone', 'the', 'information', 'helpline', 'on', '0845', '605', '5858']
# ['we', 'proved', 'that', 'most', 'of', 'the', 'ammonia', 'refrigeration', 'tables', 'are', 'wrong']
# ['75', 'the', 'fateh', 'prakash', 'palace', 'is', 'an', 'excellent', 'example', 'of', 'grandeur', 'and', 'beauty', 'it', 'reflects', 'the', 'culture', 'and', 'hospitality', 'of', 'the', 'city']
# ['shane', 'warne', 'sold', 'for', '450', '000', 'dollars']
# ['and', 'that', 'guides', 'him', 'back', 'to', 'that', 'location']
# ['6', 'the', 'required', 'money', 'for', 'any', 'judicial', 'award', 'decree', 'decision', 'which', 'has', 'been', 'passed', 'by', 'the', 'courts', 'tribunal']
# ['because', 'i', 've', 'taken', 'a', 'journey', 'to', 'brazil', 'over', 'the', 'past', 'couple', 'of', 'years']
# ['one', 'might', 'wonder', 'and', 'worry']
# ['the', 'side', 'scan', 'sonar', 'has', 'picked', 'up', 'images', 'of', 'several', 'excellent', 'geometric', 'objects', 'which', 'have', 'to', 'be', 'man', 'made', 'says', 'kathiroli', 'who', 'spent', 'sleepless', 'nights', 'on', 'sagar', 'paschimi', 'during', 'inclement', 'weather', 'in', 'the', 'gulf', 'of', 'cambay']
# ['all', 'these', 'subjects', 'later', 'on', 'became', 'big', 'discussions', 'in', 'hindi', 'literature']
# ['so', 'this', 'robot', 'is', 'actually', 'being', 'commanded']
# ['according', 'to', 'a', 'perspective', 'by', 'boddh', 'and', 'jain', 'religions', 'by', 'buddha', 'and', 'mahavira', 'idols', 'and', 'temples', 'to', 'worship', 'because', 'of', 'the', 'hindu', 'temple', 'also', 'began', 'making', 'them', 'inspired']
# ['you', 'can', 'get', 'this', 'from', 'your', 'social', 'security', 'office']
# ['after', 'that', 'japan', 'announced', 'the', 'full', 'scale', 'attack', 'on', 'china']
# ['was', 'put', 'into', 'an', 'education', 'camp']
# ['similar', 'statements', 'about', 'services', 'for', 'example', 'no', 'responsibility', 'for', 'loss', 'or', 'damage', 'to', 'garments', 'however', 'caused', 'on', 'the', 'back', 'of', 'a', 'dry', 'cleaning', 'ticket', 'are', 'not', 'illegal']
# ['as', 'the', 'copyright', 'law', 'on', 'online', 'material', 'is', 'not', 'abided', 'u', 'tube', 'thought', 'on', 'many', 'occassions', 'to', 'display', 'a', 'screen', 'with', 'the', 'following', 'message', 'to', 'the', 'users', 'while', 'uploading', 'a', 'video']
# ['discussion', 'on', 'video', 'rankings']
# ['category', 'web2', '0']
# ['as', 'locomotion', 'is', 'rather', 'difficult', 'and', 'needs', 'great', 'effort', 'in', 'running', 'waters', 'most', 'larvae', 'remain', 'securely', 'anchored', 'to', 'some', 'submerged', 'stone', 'or', 'only', 'crawl', 'about', 'with', 'the', 'help', 'of', 'special', 'hooks', 'suctorial', 'discs', 'etc']
# ['it', 'has', 'meant', 'different', 'things', 'to', 'different', 'people', 'and', 'is', 'hardly', 'left', 'with', 'any', 'one', 'definite', 'connotation']
# ['a', 'mare', 'carries', 'her', 'young', 'for', '340', 'days']
# ['for', 'our', 'vacant', 'storefronts', 'so', 'our', 'communities']
# ['soviet', 'united', 'understood', 'that', 'france', 'and', 'england', 'were', 'not', 'happy', 'along', 'with', 'it', 'and', 'if', 'germany', 'attack', 'it', 'then', 'france', 'and', 'england', 'will', 'not', 'be', 'with', 'soviet', 'united', 'so', 'he', 'make', 'deal', 'with', 'germany', 'so', 'as', 'not', 'to', 'attack', 'soviet', 'united', 'non', 'aggression', 'peck', 'and', 'sharing', 'of', 'poland', 'and', 'other', 'european', 'countries', 'among', 'themselves', 'were', 'also', 'included']
# ['here', 'he', 'is', 'leonardo', 'da', 'vinci']
# ['sheep', 'are', 'generally', 'not', 'given', 'any', 'grain', 'ration', 'except', 'when', 'they', 'are', 'to', 'be', 'fattened', 'for', 'the', 'mutton', 'market']
# ['where', 'we', 'can', 'promote', 'the', 'kinds', 'of', 'microbes']
# ['what', 'you', 're', 'trying', 'to', 'imbibe', 'what', 'you', 're', 'imbibing', 'is']
# ['what', 'kind', 'of', 'evidence', 'do', 'we', 'have', 'for', 'that']
# ['they', 're', 'being', 'done', 'right', 'now']
# ['the', 'elephants', 'and', 'horses', 'were', 'decorated', 'with', 'onions', 'men', 'wore', 'garlands', 'and', 'bracelets', 'of', 'onions', 'the', 'houses', 'and', 'streets', 'were', 'decorated', 'with', 'onion', 'banners']
# ['in', 'the', 'mahabharata', 'that', 'ws', 'shown', 'on', 'dooradarshan', 'the', 'bhagwat', 'gita', 'was', 'a', 'special', 'attraction', 'a', 'different', 'serial', 'was', 'made', 'by', 'sri', 'krishna', 'who', 'acted', 'in', 'the', 'original', 'mahabharata', 'which', 'was', 're', 'broadcasted', 'taking', 'clue', 'from', 'the', 'immense', 'pathos', 'and', 'sentiments', 'that', 'it', 'carried']
# ['those', 'milestones', 'in', 'a', 'life', 'that', 'people', 'want', 'to', 'celebrate']
# ['is', 'by', 'teaching', 'children', 'perspectives']
# ['2', 'promises', 'decision', 'is', 'concise', 'manner', 'in', 'which', 'to', 'complete', 'the', 'defense', 'introduce', 'abhiyukutt']
# ['rourkela', 's', 'contribution', 'therefore', 'could', 'be', 'reckoned', 'with', 'only', 'in', 'the', 'third', 'plan']
# ['the', 'body', 'weight', 'is', '11', 'kilograms', 'for', 'the', 'young', 'torn', 'and', '7', 'kilograms', 'for', 'the', 'turkey', 'hen', 'of', 'this', 'breed']
# ['other', 'linux', 'you', 'tube', 'video', 'showed', 'the', 'video', 'to', 'the', 'website', 'will', 'not', 'embedded', 'more']
# ['the', 'parliament', 'of', 'india', 'and', 'the', 'parliamentary', 'institutions', 'as', 'we', 'know', 'them', 'today', 'had', 'an', 'organic', 'growth', 'on', 'the', 'indian', 'soil']
# ['laughter']
# ['women', 'marching', 'through', 'the', 'streets', 'daring', 'the', '50', '000', 'men', 'watching', 'in', 'awe', 'from', 'their', 'rooftops', 'to', 'arouse', 'their', 'animosity']
# ['the', 'knowledge', 'about', 'the', 'arrival', 'of', 'this', 'day', 'is', 'with', 'god', 'alone']
# ['and', 'i', 'want', 'to', 'just', 'make', 'one', 'point', 'about', 'this', 'investment']
# ['so', 'let', 's', 'talk', 'about', 'those', 'three', 'a', 's']
# ['it', 'was', 'a', 'rare', 'gem']
# ['importance', 'of', 'sanskrit', 'language']
# ['it', 'was', 'come', 'dark', 'and', 'rain', 'will', 'make', 'you', 'weary', 'and', 'tired']
# ['to', 'bring', 'water', 'from', 'the', 'himalayas']
# ['or', 'if', 'you', 'are', 'working', 'but', 'do', 'not', 'have', 'enough', 'money', 'coming', 'in', 'you', 'may', 'need', 'help', 'to', 'make', 'ends', 'meet']
# ['creaked', 'left', 'clues']
# ['and', 'we', 'expect', 'to', 'take', 'data', 'in', 'june', 'or', 'july']
# ['in', 'almoda', 'jail', 'again', 'his', 'health', 'deteriorated']
# ['and', 'so', 'needless', 'to', 'say', 'over', 'those', 'years']
# ['dr', 'v', 'when', 'you', 'grow', 'in', 'spiritual', 'consciousness']
# ['you', 'can', 'go', 'to', 'the', 'tribunal', 'on', 'your', 'own', 'or', 'voluntary', 'organisations', 'or', 'parents', 'groups', 'can', 'help', 'you', 'prepare', 'your', 'case', 'and', 'go', 'with', 'you']
# ['and', 'even', 'that', '95', 'percent', 'student']
# ['it', 'is', 'more', 'and', 'more', 'often']
# ['these', 'animals', 'are', 'fiery', 'active', 'and', 'are', 'noted', 'for', 'their', 'power', 'of', 'endurance']
# ['it', 's', 'got', 'an', 'amazing', 'user', 'experience']
# ['in', 'fact', 'badruddin', 'was', 'to', 'play', 'such', 'a', 'major', 'role', 'in', 'the', 'early', 'years', 'of', 'the', 'congress', 'that', 'half', 'a', 'century', 'later', 'mahatma', 'gandhi', 'wrote', 'that', 'badruddin', 'tyabji', 'was', 'for', 'years', 'a', 'decisive', 'factor', 'in', 'the', 'deliberations', 'of', 'the', 'congress']
# ['it', 'will', 'come', 'when', 'ordinary', 'indians', 'see', 'a', 'visible', 'improvement', 'in', 'their', 'physical', 'environment']
# ['it', 'can', 'be', 'only', 'know', 'after', 'read', 'text', 'of', 'mahadevi', 'verma', 'that', 'how', 'much', 'an', 'creature', 'can', 'be', 'got', 'without', 'imagination', 'and', 'poetry']
# ['this', 'words', 'comes', 'like', 'this', 'because', 'umpire', 'says', 'over', 'means', 'finished']
# ['thats', 'why', 'ibane', 'sina', 'is', 'known', 'as', 'father', 'of', 'modern', 'theraphy']
# ['with', 'you', 'and', 'with', 'i', 'and', 'so', 'on']
# ['do', 'you', 'know', 'enough', 'about', 'drugs']
# ['a', 'recent', 'aspect', 'of', 'aeroplane', 'noise', 'is', 'the', 'sonic', 'boom']
# ['khyber', 'pass', 'provides', 'a', 'passage', 'to', 'cross', 'the', 'great', 'range']
# ['the', 'people', 'of', 'multan', 'used', 'to', 'tell', 'me', 'that', 'they', 'have', 'no', 'varshakala', 'but', 'the', 'more', 'northern', 'provinces', 'nearer', 'the', 'mountains', 'have', 'the', 'varshakala']
# ['caraka', 'lrb', 'p', '74', 'rrb']
# ['well', 'one', 'thing', 'to', 'notice', 'is', 'that', 'we']
# ['in', 'most', 'cases', 'an', 'individual', 'cannot', 'afford', 'proper', 'legal', 'services', 'whereas', 'corporations', 'can', 'retain', 'the', 'services', 'of', 'some', 'of', 'the', 'best', 'legal', 'practitioners']
# ['rather', 'than', 'preceeding', 'the', 'insurgency']
# ['so', 'i', 'think', 'that', 'actually', 'step', 'two', 'that', 'i', 'called', 'a', 'step', 'a', 'moment', 'ago']
# ['mosque', 'is', 'not', 'only', 'the', 'prayer', 'center', 'but', 'also', 'here', 'muslims', 'community', 'people', 'thought', 'and', 'principles', 'are', 'studied']
# ['look', 'at', 'this']
# ['i', 'know', 'it', 'sounds', 'like', 'a', 'little', 'thing', 'to', 'you', 'but', 'laughter']
# ['on', 'internet']
# ['premchand', 's', 'writing', 'was', 'unique', 'in', 'terms', 'of', 'literature']
# ['as', 'soon', 'as', 'i', 'came', 'out', 'of', 'my', 'coma']
# ['the', 'larva', 'hatching', 'from', 'the', 'egg', 'tunnels', 'into', 'the', 'soft', 'tissues', 'and', 'makes', 'a', 'cocoon', 'of', 'the', 'cocoanut', 'fibres', 'before', 'pupating']
# ['didn', 't', 'really', 'work', 'out', 'that', 'way', 'did', 'it']
# ['finance', 'management']
# ['the', 'basis', 'of', 'shiya', 'and', 'sunni', 'sects']
# ['writing', 'of', 'mahabharath', 'by', 'god', 'ganesh', 'listening', 'to', 'hermit', 'vyasa']
# ['always', 'have', 'to', 'be', 'in', 'the', 'same', 'place']
# ['if', 'yes', 'to', 'both', 'ask', 'your', 'jobcentre', 'about', 'new', 'deal', 'for', 'partners', 'of', 'unemployed', 'people']
# ['dhrudharashtra', 'and', 'ghandhari', 's', 'eldest', 'among', 'their', '200', 'sons']
# ['sat', 'visit']
# ['english', 'ways', 'and', 'customs', 'even', 'the', 'english', 'language', 'was', 'as', 'yet', 'strange', 'and', 'unknown', 'to', 'most', 'indians']
# ['and', 'i', 'm', 'here', 'to', 'say']
# ['your', 'dealer', 'may', 'have', 'access', 'to', 'a', 'database', 'of', 'vehicle', 'mileages']
# ['he', 'started', 'the', 'slogan', 'of', 'jai', 'hind', 'which', 'became', 'the', 'national', 'slogan', 'of', 'india']
# ['babhruvahan', 'son', 'of', 'arjun', 'and', 'chitragtha']
# ['by', 'judicious', 'selection', 'and', 'by', 'preferring', 'that', 'which', 'is', 'better', 'to', 'that', 'which', 'is', 'good', 'which', 'way', 'leads', 'to', 'a', 'laudable', 'end']
# ['i', 'stagger', 'to', 'think', 'that', 'these', 'problems', 'do', 'not', 'even', 'figure', 'in', 'their', 'programmes']
# ['are', 'they', 'friend', 'or', 'foe', 'is', 'there', 'anybody', 'he', 'can', 'go', 'mate', 'with']
# ['i', 'find', 'it', 'quite', 'absurd', 'when', 'i', 'learn', 'that', 'people', 'want', 'to', 'suppress', 'a', 'language', 'or', 'script', 'anywhere']
# ['cuttings', 'from', 'that', 'tree', 'are', 'ripening', 'their', 'fruit', 'in', 'new', 'zealand', 'and', 'australia', 'even', 'today']
# ['the', 'bomb', 'exploded', 'owing', 'to', 'the', 'official', 'class', 'having', 'tried', 'the', 'patience', 'of', 'the', 'bengali', 'youth']
# ['after', 'being', 'bachelor', 'he', 'entered', 'in', 'defense', 'research', 'and', 'development', 'institute', 'to', 'work', 'on', 'haver', 'craft', 'project']
# ['can', 'you', 'feel', 'their', 'anger']
# ['he', 'begs', 'to', 'be', 'forgiven']
# ['and', 'what', 'is', 'it', 'meant', 'for', 'anybody']
# ['from', 'the', 'office', 'desk']
# ...
# ['yet', 'three', 'centuries', 'later', 'the', 'famous', 'botanist', 'professor', 'lindley', 'when', 'confronted', 'with', 'the', 'potato', 'blight', 'which', 'brought', 'famine', 'to', 'ireland', 'in', '1846', 'put', 'the', 'cart', 'before', 'the', 'horse', 'and', 'held', 'that', 'mildew', 'was', 'the', 'consequence', 'and', 'not', 'the', 'cause', 'of', 'the', 'disease']
# ['in', 'order', 'to', 'acquire', 'a', 'higher', 'status', 'in', 'hindu', 'society', 'they', 'claimed', 'to', 'be', 'the', 'these', 'rajputs', 'infused', 'fresh', 'blood', 'into', 'the', 'enervated', 'body', 'of', 'hindu', 'society', 'and', 'created', 'a', 'stir', 'and', 'movement', 'in', 'its', 'stagnant', 'intellectual', 'and', 'cultural', 'life']
# ['in', 'pakistan', 's', 'time', 'honoured', 'tradition', 'of', 'power', 'politics', 'king', 'makers', 'seldom', 'outlast', 'the', 'king']
# ['camel', 'is', 'a', 'ruminant', 'like', 'cattle', 'sheep', 'and', 'goats']
# ['kalpana', 'is', 'first', 'lady', 'whose', 'birth', 'origin', 'is', 'india', 'to', 'fly', 'in', 'airspace', 'and', 'second', 'person', 'to', 'fly', 'of', 'indian', 'origin']
# ['when', 'compared', 'with', 'the', 'relationship', 'of', 'weight', 'of', 'the', 'baby', 'to', 'that', 'of', 'the', 'mother', 'in', 'case', 'of', 'animals', 'of', 'other', 'species', 'the', 'weight', 'of', 'the', 'baby', 'elephant', 'is', 'very', 'small']
# ['no', 'nation', 'can', 'afford', 'to', 'lose', 'its', 'people', 's', 'hearts']
# ['kapiblah', 'branch']
# ['besides', 'being', 'a', 'place', 'of', 'worship', 'it', 'was', 'the', 'focal', 'point', 'of', 'the', 'town', 'or', 'village', 'all', 'the', 'activities', 'of', 'the', 'village', 'centred', 'round', 'the', 'temple']
# ['he', 'has', 'seen', 'many', 'changes', 'in', 'foreign', 'countries', 'and', 'these', 'changes', 'have', 'profoundly', 'affected', 'and', 'influenced', 'his', 'outlook']
# ['the', 'first', 'batsman', 'of', 'the', 'world', 'making', '13000', 'runs', 'in', 'test', 'cricket']
# ['another', '1', '5', 'lakh', 'tonne', 'capacity', 'was', 'shared', 'about', 'equally', 'between', 'tamil', 'nadu', 'and', 'andhra']
# ['the', 'fact', 'that', 'we', 'are', 'still', 'waiting', 'for', 'justice', 'in', 'the', 'bofors', 'case', 'nearly', '15', 'years', 'on', 'speaks', 'for', 'itself']
# ['in', 'this', 'respect', 'the', 'contrast', 'between', 'the', 'indian', 'mind', 'and', 'the', 'modern', 'western', 'mind', 'stands', 'out', 'clearly']
# ['the', 'preamble', 'of', 'indian', 'constitution', 'is', 'influenced', 'from', 'american', 'constitution', 'and', 'considered', 'best', 'among', 'the', 'world']
# ['the', 'methodology', 'was', 'inadequate', 'and', 'this', 'inquiry', 'has', 'not', 'relied', 'on', 'the', 'internal', 'report', 'but', 'has', 'gone', 'back', 'to', 'the', 'primary', 'sources']
# ['with', 'the', 'expected', 'increase', 'in', 'power', 'plants', 'and', 'their', 'capacity', 'the', 'tonnage', 'of', 'fly', 'ash', 'is', 'estimated', 'to', 'reach', 'about', '3', '5', 'lakhs', 'tonnes', 'a', 'day']
# ['that', 'makes', '12', 'of', 'them']
# ['he', 'has', 'to', 'observe', 'celibacy', 'or', 'abstain', 'himself', 'from', 'sex']
# ['bharat', 'mata', 'was', 'not', 'a', 'lady', 'lovely', 'and', 'forlorn', 'with', 'long', 'tresses', 'reaching', 'to', 'the', 'ground', 'as', 'sometimes', 'shown', 'in', 'fanciful', 'pictures']
# ['secondary', 'failure', 'to', 'drug', 'may', 'ensue', 'after', 'a', 'year', 'or', 'so']
# ['full', 'majority', 'more', 'than', '50', 'of', 'parliament', 'members', 'including', 'vacant', 'seats', 'support', 'of', '273', 'in', 'loksabha', '123', 'in', 'rajya', 'sabha', 'it', 'has', 'political', 'importance', 'not', 'legal', 'importance']
# ['muslim', 'scholers', 'not', 'only', 'translated']
# ['a', 'muhatasib', 'could', 'admonish', 'and', 'report', 'cases', 'to', 'the', 'ruler', 'but', 'did', 'not', 'have', 'powers', 'to', 'imprison', 'anyone', 'because', 'the', 'power', 'to', 'imprison', 'belonged', 'to', 'the', 'qazi']
# ['which', 'we', 'in', 'turn', 'breathe', 'green', 'roofs', 'also', 'retain', 'up', 'to', '75', 'percent', 'of', 'rainfall']
# ['will', 'treatment', 'be', 'uncomfortable']
# ['again', 'using', 'all', 'natural', 'gestures']
# ['in', 'order', 'to', 'make', 'indians', 'better', 'customers', 'for', 'their', 'goods', 'and', 'more', 'loyal', 'subjects', 'of', 'the', 'raj', 'the', 'british', 'made', 'every', 'effort', 'to', 'impose', 'on', 'india', 'the', 'colony', 'the', 'culture', 'of', 'britain', 'the', 'metropolis']
# ['he', 'had', 'secured', 'an', 'assurance', 'from', 'the', 'president', 'and', 'others', 'prominent', 'in', 'the', 'government', 'that', 'a', 'more', 'liberal', 'policy', 'would', 'be', 'adopted', 'and', 'all', 'efforts', 'would', 'be', 'made', 'to', 'satisfy', 'the', 'immediate', 'demands', 'of', 'workers', 'and', 'peasants']
# ['and', 'then', 'as', 'the', 'ammonia', 're', 'evaporates', 'and', 'combines', 'with', 'the', 'water']
# ['it', 'has', 'rocked', 'the', 'music', 'industry']
# ['india', 'too', 'will', 'be', 'affected', 'by', 'the', 'large', 'scale', 'changes', 'in', 'the', 'ozone', 'layer']
# ['our', 'sole', 'purpose', 'was', 'to', 'make', 'the', 'deaf', 'hear', 'and', 'give', 'the', 'heedless', 'a', 'timely', 'warning']
# ['the', 'articles', 'related', 'to', 'research', 'work']
# ['the', 'war', 'between', 'england', 'and', 'germany', 'began', 'in', 'august', '1914']
# ['before', 'we', 'review', 'the', 'expansion', 'of', 'the', 'railways', 'after', '1853', 'we', 'may', 'briefly', 'describe', 'the', 'guarantee', 'system', 'under', 'which', 'railways', 'were', 'built', 'in', 'the', 'next', 'fifteen', 'years', 'and', 'which', 'came', 'in', 'for', 'criticism', 'for', 'its', 'adverse', 'effect', 'on', 'railway', 'finances']
# ['college', 'only', 'for', 'the', 'poor']
# ['power', 'distribution', 'principle', 'in', 'indian', 'constitution']
# ['late', 'puranchandra', 'gupta', 'never', 'be', 'your', 'newspaper', 'feud', 'not', 'of', 'their', 'echasskathy', 'doug']
# ['part', 'iii', 'articles', '29', '30', 'part', 'v', 'article', '120', 'part', 'vi', 'article', '210', 'part', 'xvii', 'articles', '343', '351', 'part', 'xxii', 'article', '394a', 'and', 'eighth', 'schedule', 'although', 'there', 'is', 'a', 'separate', 'part', 'part', 'xvii', 'devoted', 'to', 'official', 'language', 'provisions', 'pertaining', 'to', 'language', 'are', 'spread', 'over', 'different', 'parts', 'and', 'chapters', 'of', 'the', 'constitution']
# ['you', 'won', 't', 'find', 'water', 'in', 'this', 'slide']
# ['they', 'are', 'afraid', 'that', 'they', 'will', 'lose', 'the', 'favour', 'of', 'europeans', 'but', 'as', 'they', 'have', 'not', 'the', 'courage', 'to', 'give', 'their', 'true', 'reasons', 'openly', 'they', 'pretend', 'that', 'they', 'oppose', 'the', 'congress', 'because', 'they', 'think', 'it', 'is', 'not', 'good']
# ['unique', 'keyboard']
# ['head', 'lice', 'feed', 'by', 'biting', 'and', 'sucking', 'blood', 'through', 'the', 'scalp', 'of', 'their', 'host']
# ['died', 'dayanand', 'sahaya', '70', 'rajya', 'sabha', 'mp', 'in', 'a', 'road', 'accident', 'at', 'makhdumpur', 'bihar']
# ['as', 'a', 'rule', 'experimentation', 'with', 'drugs', 'such', 'as', 'cannabis', 'and', 'lsd', 'does', 'not', 'start', 'until', 'mid', 'late', 'teens']
# ['we', 'are', 'often', 'accused', 'of', 'preaching', 'the', 'class', 'war', 'and', 'of', 'widening', 'the', 'distance', 'between', 'the', 'classes']
# ['mahadevi', 'has', 'seen', 'india', 'before', 'independence', 'and', 'after', 'too']
# ['ted', 'bundy', 'was', 'very', 'fond', 'of', 'abducting', 'and', 'raping']
# ['this', 'affected', 'agronomy', 'greatly']
# ['and', 'then', 'engage', 'with', 'them', 'as', 'a', 'partner']
# ['premchand', 'issued', 'post', 'ticket', 'thumb']
# ['when', 'the', 'mongols', 'defeated', 'the', 'abbasis', 'in', 'baghdad', 'in', '1258', 'the', 'abbasi', 'caliph', 'sought', 'refuge', 'like', 'a', 'nameless', 'personality', 'with', 'the', 'mamluk', 'kingdom', 'of', 'egypt']
# ['she', 'was', 'chief', 'guest', 'of', 'ending', 'ceremony', 'of', 'third', 'world', 'hindi', 'conference', 'planned', 'in', '1986']
# ['both', 'bhagat', 'singh', 'and', 'b', 'k', 'dutt', 'looked', 'cheerful', 'and', 'kept', 'smiling', 'all', 'along']
# ['at', 'first', 'it', 'was', 'going', 'very', 'well']
# ['permission', 'of', 'president', 'should', 'be', 'there']
# ['praja', 'bharat']
# ['the', 'average', 'height', 'of', 'the', 'circus', 'elephant', 'is', '2', '2', 'metres']
# ['through', 'regional', 'committee', 'of', 'mqm', 'peshawar']
# ['i', 'need', 'you', 'to', 'go', 'upstairs', 'past', 'the', 'fire']
# ['it', 'incessantly', 'drivers', 'its', 'victims', 'and', 'yet', 'leads', 'them', 'nowhere']
# ['hiv', 'aids', 'and', 'sexual', 'health', 'targets', 'to']
# ['asamiya']
# ['fatimid', 'dynasty', '909', '1171', 'who', 'were', 'shia', 'had', 'occupied', 'some', 'parts', 'of', 'north', 'africa', 'and', 'had', 'established', 'its', 'independent', 'caliphate']
# ['fluoride', '8']
# ['so', 'will', 'we', 'see', 'a', 'plethora', 'of', 'rural', 'sagas', 'or', 'even', 'sports', 'centred', 'films']
# ['therefore', 'to', 'test', 'them', 'dhrupad', 'had', 'called', 'them', 'to', 'theirjewelry', 'room']
# ['the', 'used', 'dung', 'slurry', 'can', 'be', 'reused', 'as', 'manure']
# ['his', 'son', 'rajendra', 'chola', 'further', 'increased', 'his', 'dominion', 'by', 'annexing', 'the', 'region', 'along', 'the', 'bay', 'of', 'bengal']
# ['masons', 'carpenters', 'and', 'labourers', 'jostle', 'with', 'worshippers', 'round', 'the', 'year']
# ['they', 'could', 'put', 'this', 'ishta', 'linga', 'in', 'a', 'piece', 'of', 'cloth', 'and', 'tie', 'it', 'to', 'the', 'neck', 'or', 'keep', 'it', 'in', 'a', 'small', 'casket', 'and', 'wear', 'it', 'round', 'the', 'neck', 'in', 'such', 'a', 'way', 'that', 'it', 'rested', 'on', 'the', 'chest']
# ['why', 'do', 'they', 'not', 'set', 'deadlines', 'for', 'at', 'least', 'cases', 'of', 'vital', 'public', 'interest', 'like', 'the', 'uphaar', 'cinema', 'case', 'in', 'which', 'more', 'than', '50', 'innocent', 'citizens', 'lost', 'their', 'lives', 'because', 'of', 'the', 'criminal', 'negligence', 'of', 'municipal', 'officials']
# ['there', 's', 'a', 'lot', 'of', 'really', 'great', 'computational', 'work', 'you', 'can', 'do']
# ['their', 'present', 'habit', 'of', 'considering', 'that', 'a', 'knowledge', 'of', 'urdu', 'and', 'arabic', 'was', 'sufficient', 'knowledge', 'for', 'any', 'man', 'had', 'the', 'result', 'of', 'depriving', 'them', 'of', 'gainful', 'employment']
# ['and', 'summoned', 'the', 'courage', 'through', 'a', 'lot', 'of', 'tears']
# ['but', 'this', 'provision', 'does', 'not', 'prevent', 'the', 'parliament', 'from', 'subsequently', 'amending', 'varying', 'or', 'even', 'repealing', 'the', 'law', 'made', 'by', 'the', 'state', 'legislature']
# ['that', 's', 'a', 'good', 'close', 'up', 'of', 'that', 'one']
# ['and', 'he', 's', 'discussing', 'what', 'sort', 'of', 'cassava', 'they', 'will', 'plant']
# ['into', 'a', 'giant', 'chalkboard', 'and', 'stenciled', 'it']
# ['such', 'a', 'front', 'would', 'split', 'anti', 'incumbency', 'votes', 'and', 'indirectly', 'help', 'the', 'dmk', 'alliance', 'retain', 'power']
# ['surdas', 'on', 'wikipedia']
# ['this', 'will', 'give', 'you', 'and', 'the', 'lea', 'time', 'to', 'produce', 'this']
# ['it', 'requires', 'that', 'all', 'of', 'us', 'have', 'the', 'courage', 'and', 'the', 'patience']
# ['democracy', 'means', 'nothing', 'to', 'them', 'nor', 'freedom', 'though', 'they', 'talk', 'loudly', 'of', 'them', 'their', 'main', 'concern', 'is', 'the', 'protection', 'of', 'their', 'vested', 'interests', 'and', 'privileges', 'the', 'marxian', 'philosophy', 'appeals', 'to', 'me', 'in', 'a', 'broad', 'sense', 'and', 'helps', 'me', 'to', 'understand', 'the', 'processes', 'of', 'history']
# ['by', 'flowing', 'like', 'this', 'for', '200', 'k', 'm', 'through', 'mountaneous', 'course', 'and', 'passing', 'through', 'rishikesh', 'the', 'river', 'ganga', 'for', 'the', 'first', 'time', 'touches', 'the', 'plains', 'at', 'haridwar']
# ['hindustan', 'samachar', 'uni', 'coded']
# ['the', 'sudden', 'fall', 'of', 'malaya', 'singapore', 'rangoon', 'and', 'the', 'andamans', 'in', 'succession', 'was', 'a', 'tremendous', 'shock', 'to', 'the', 'britishers', 'and', 'this', 'was', 'a', 'great', 'setback', 'to', 'their', 'prestige', 'among', 'the', 'allies']
# ['google', 'author']
# ['the', 'die', 'was', 'cast']
# ['devotional', 'period', '1375', '1700']
# ['need', 'not', 'be', 'so', 'called', 'jugaad', 'need', 'not', 'be', 'some', 'kind', 'of', 'makeshift', 'arrangement']
# ['between', 'the', 'ages', 'of', 'four', 'and', 'seven', 'most', 'children', 'learn', 'to', 'read', 'but', 'even', 'when', 'they', 'can', 'read', 'you', 'should', 'still', 'try', 'to', 'read', 'to', 'them', 'as', 'often', 'as', 'possible']
# ['this', 'work', 'was', 'revolutionary', 'work', 'in', 'wmoen', 'education', 'at', 'that', 'time']
# ['if', 'we', 'do', 'so', 'we', 'shall', 'be', 'hurting', 'our', 'own', 'future', 'prospects', 'and', 'the', 'muslims', 'will', 'continue', 'to', 'be', 'used', 'as', 'vote', 'banks', 'by', 'our', 'adversaries']
# ['the', 'use', 'of', 'line', 'source', 'dispersion', 'and', 'airports', 'road', 'air', 'dispersion', 'modeling']
# ['it', 'keeps', 'forwarding', 'you', 'to', 'more', 'and', 'more', 'advanced', 'modules']
# ['let', 's', 'figure', 'out', 'how', 'long', 'it', 'takes', 'a', 'race', 'car', 'to', 'go', 'a', 'certain', 'distance']
# ['travelling']
# ['not', 'only', 'this', 'it', 'has', 'even', 'turned', 'the', 'illiterate', 'people', 'of', 'registan', 'into', 'gentle', 'and', 'polite', 'the', 'influence', 'was', 'so', 'powerful', 'that', 'no', 'one', 'could', 'overtake', 'them', 'after', 'thousands', 'of', 'years']
# ['because', 'when', 'you', 'are', 'a', 'developing', 'country']
# ['the', 'pishtak', 'arch', 'are', 'ornamented', 'with', 'calligraphy']
# ['parliament', 'may', 'by', 'law', 'regulate', 'the', 'procedure', 'for', 'the', 'purpose', 'of', 'timely', 'completion', 'of', 'the', 'financial', 'business', 'lrb', 'article', '119', 'rrb']
# ['is', 'if', 'we', 'want', 'that', 'to', 'become', 'our', 'reality']
# ['the', 'salvation', 'of', 'souls', 'son', 'of', 'sgar', 'sanshuman', 'attempted', 'unsuccessfully', 'and', 'then', 'by', 'anshuman', 's', 'son', 'dilip']
# ['africa', 'has', 'not', 'done', 'bad']
# ['about', '85', 'per', 'cent', 'of', 'our', 'tea', 'production', 'was', 'directly', 'exported', 'to', 'britain', 'and', 'was', 'sold', 'through', 'special', 'auctions', 'held', 'twice', 'a', 'week', 'in', 'london', 'thus', 'the', 'fate', 'of', 'indian', 'tea', 'was', 'linked', 'with', 'these', 'auctions']
# ['certain', 'other', 'tests', 'may', 'be', 'necessary', 'for', 'special', 'cases']
# ['it', 'is', 'now', 'widening', 'its', 'boundaries', 'and', 'it', 'may', 'invade', 'the', 'so', 'called', 'invisible', 'world', 'before', 'long', 'and', 'help', 'us', 'to', 'understand', 'this', 'purpose', 'of', 'life', 'in', 'its', 'widest', 'sense', 'or', 'at', 'least', 'give', 'us', 'some', 'glimpses', 'which', 'illumine', 'the', 'problem', 'of', 'human', 'existence']
# ['examples', 'of', 'art', 'deco', 'construction', 'can', 'be', 'found', 'around', 'marine', 'drive', 'and', 'oval', 'ground', 'areas']
# ['and', 'put', 'it', 'in', 'our', 'cheeks']
# ['as', 'for', 'the', 'other', 'derivatives', 'of', 'sulphur', 'the', 'country', 's', 'needs', 'of', 'iron', 'copper', 'sodium', 'etc', 'sulphates', 'were', 'limited', 'and', 'the', 'production', 'achieved', 'after', 'the', 'war', 'was', 'generally', 'adequate']
# ['its', 'complicated', 'functioning', 'is', 'defined', 'thus', 'in', 'a', 'popular', 'riddle']
# ['they', 've', 'just', 'won', 'four', 'government', 'contracts', 'to', 'build', 'off', 'their', '100', 'ambulances']

# %%
import unicodedata
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# %%
import re
def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)
    w = w.rstrip().strip()
    return w

# %%
def hindi_preprocess_sentence(w):
    w = w.rstrip().strip()
    return w

# %%
PATH='Hindi_English_Truncated_Corpus.csv'
def create_dataset(path=PATH):
    lines=pd.read_csv(path,encoding='utf-8')
    lines=lines.dropna()
    lines = lines[lines['source']=='ted']
    en = []
    hd = []
    for i, j in zip(lines['english_sentence'], lines['hindi_sentence']):
        en_1 = [preprocess_sentence(w) for w in i.split(' ')]
        en_1.append('<end>')
        en_1.insert(0, '<start>')
        hd_1 = [hindi_preprocess_sentence(w) for w in j.split(' ')]
        hd_1.append('<end>')
        hd_1.insert(0, '<start>')
        en.append(en_1)
        hd.append(hd_1)
    return hd, en

# %%
def max_length(tensor):
    return max(len(t) for t in tensor)

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)
  tensor = lang_tokenizer.texts_to_sequences(lang)
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,padding='post')
  return tensor, lang_tokenizer

# %%
def load_dataset(path=PATH):
    targ_lang, inp_lang = create_dataset(path)
    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)
    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
import tensorflow as tf
import pandas as pd
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(PATH)
max_length_targ, max_length_inp = max_length(target_tensor), max_length(input_tensor)

# %%
from sklearn.model_selection import train_test_split
input_tensor_train,input_tensor_val,target_tensor_train,target_tensor_val=train_test_split(input_tensor,target_tensor,test_size=0.2)
print(len(input_tensor_train), len(input_tensor_val),len(target_tensor_train),len(target_tensor_val))
# Out:
# 31904 7977 31904 7977

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 50 ----> or
# 11 ----> is
# 3 ----> the
# 235 ----> whole
# 423 ----> design
# 6 ----> of
# 3 ----> the
# 377 ----> system
# 2435 ----> wrong ?
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 51 ----> या
# 10160 ----> यत्र
# 4 ----> के
# 337 ----> पूरे
# 2163 ----> डिज़ाइन
# 152 ----> मे
# 29 ----> ही
# 24119 ----> गडगड
# 148 ----> है?
# 2 ----> <end>

# %% [markdown]
# # Create Dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 128
units = 256
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# # Encoder

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# # Attention Mechanism

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    hidden_with_time_axis = tf.expand_dims(query, 1)
    score = self.V(tf.nn.tanh(
        self.W1(values) + self.W2(hidden_with_time_axis)))
    attention_weights = tf.nn.softmax(score, axis=1)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)
    return context_vector, attention_weights

# %% [markdown]
# # Decoder

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    context_vector, attention_weights = self.attention(hidden, enc_output)
    x = self.embedding(x)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
    output, state = self.gru(x)
    output = tf.reshape(output, (-1, output.shape[2]))
    x = self.fc(output)
    return x, state, attention_weights

decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# # Optimizer

# %%
import os
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)
  mask = tf.cast(mask, dtype=loss_.dtype)
#   print(type(mask))
  loss_ *= mask
  return tf.reduce_mean(loss_)
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# # Training

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0
  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
    # Teacher forcing
    for t in range(1, targ.shape[1]):
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)
      loss += loss_function(targ[:, t], predictions)
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))
  variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))
  return batch_loss

# %%
import time
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()
  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0
  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss
    if batch % 100 == 0:
        print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                     batch,
                                                     batch_loss.numpy()))
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 3.1017
# Epoch 1 Batch 100 Loss 2.0544
# Epoch 1 Batch 200 Loss 2.0534
# Epoch 1 Batch 300 Loss 2.0732
# Epoch 1 Batch 400 Loss 1.9940
# Epoch 1 Loss 1.9501
# Time taken for 1 epoch 126.47015810012817 sec
#
# Epoch 2 Batch 0 Loss 1.8007
# Epoch 2 Batch 100 Loss 1.6147
# Epoch 2 Batch 200 Loss 1.7262
# Epoch 2 Batch 300 Loss 1.9534
# Epoch 2 Batch 400 Loss 1.7280
# Epoch 2 Loss 1.7453
# Time taken for 1 epoch 41.8831672668457 sec
#
# Epoch 3 Batch 0 Loss 1.6606
# Epoch 3 Batch 100 Loss 1.7747
# Epoch 3 Batch 200 Loss 1.7794
# Epoch 3 Batch 300 Loss 1.5419
# Epoch 3 Batch 400 Loss 1.8096
# Epoch 3 Loss 1.6520
# Time taken for 1 epoch 41.20238423347473 sec
#
# Epoch 4 Batch 0 Loss 1.6934
# Epoch 4 Batch 100 Loss 1.5737
# Epoch 4 Batch 200 Loss 1.5775
# Epoch 4 Batch 300 Loss 1.6396
# Epoch 4 Batch 400 Loss 1.6350
# Epoch 4 Loss 1.5561
# Time taken for 1 epoch 40.826860189437866 sec
#
# Epoch 5 Batch 0 Loss 1.5108
# Epoch 5 Batch 100 Loss 1.3635
# Epoch 5 Batch 200 Loss 1.4130
# Epoch 5 Batch 300 Loss 1.3787
# Epoch 5 Batch 400 Loss 1.5416
# Epoch 5 Loss 1.4561
# Time taken for 1 epoch 39.73736023902893 sec
#
# Epoch 6 Batch 0 Loss 1.4760
# Epoch 6 Batch 100 Loss 1.3102
# Epoch 6 Batch 200 Loss 1.3595
# Epoch 6 Batch 300 Loss 1.3346
# Epoch 6 Batch 400 Loss 1.3323
# Epoch 6 Loss 1.3592
# Time taken for 1 epoch 40.88821005821228 sec
#
# Epoch 7 Batch 0 Loss 1.2242
# Epoch 7 Batch 100 Loss 1.2528
# Epoch 7 Batch 200 Loss 1.2787
# Epoch 7 Batch 300 Loss 1.3172
# Epoch 7 Batch 400 Loss 1.3043
# Epoch 7 Loss 1.2669
# Time taken for 1 epoch 41.0805823802948 sec
#
# Epoch 8 Batch 0 Loss 1.1162
# Epoch 8 Batch 100 Loss 1.2051
# Epoch 8 Batch 200 Loss 1.1130
# Epoch 8 Batch 300 Loss 1.2635
# Epoch 8 Batch 400 Loss 1.2033
# Epoch 8 Loss 1.1789
# Time taken for 1 epoch 40.851969480514526 sec
#
# Epoch 9 Batch 0 Loss 1.0027
# Epoch 9 Batch 100 Loss 1.1296
# Epoch 9 Batch 200 Loss 0.9796
# Epoch 9 Batch 300 Loss 1.1579
# Epoch 9 Batch 400 Loss 1.0515
# Epoch 9 Loss 1.0959
# Time taken for 1 epoch 39.5520761013031 sec
#
# Epoch 10 Batch 0 Loss 1.1435
# Epoch 10 Batch 100 Loss 1.0811
# Epoch 10 Batch 200 Loss 1.0552
# Epoch 10 Batch 300 Loss 1.0937
# Epoch 10 Batch 400 Loss 1.0811
# Epoch 10 Loss 1.0169
# Time taken for 1 epoch 41.844788551330566 sec
#
# Epoch 11 Batch 0 Loss 0.8357
# Epoch 11 Batch 100 Loss 0.9460
# Epoch 11 Batch 200 Loss 0.9692
# Epoch 11 Batch 300 Loss 0.9236
# Epoch 11 Batch 400 Loss 0.9966
# Epoch 11 Loss 0.9416
# Time taken for 1 epoch 39.90893006324768 sec
#
# Epoch 12 Batch 0 Loss 0.7827
# Epoch 12 Batch 100 Loss 0.8788
# Epoch 12 Batch 200 Loss 0.9798
# Epoch 12 Batch 300 Loss 0.9397
# Epoch 12 Batch 400 Loss 0.9632
# Epoch 12 Loss 0.8711
# Time taken for 1 epoch 40.10840725898743 sec
#
# Epoch 13 Batch 0 Loss 0.7200
# Epoch 13 Batch 100 Loss 0.7524
# Epoch 13 Batch 200 Loss 0.7566
# Epoch 13 Batch 300 Loss 0.8596
# Epoch 13 Batch 400 Loss 0.8769
# Epoch 13 Loss 0.8063
# Time taken for 1 epoch 39.71718645095825 sec
#
# Epoch 14 Batch 0 Loss 0.7987
# Epoch 14 Batch 100 Loss 0.7404
# Epoch 14 Batch 200 Loss 0.7817
# Epoch 14 Batch 300 Loss 0.7291
# Epoch 14 Batch 400 Loss 0.7117
# Epoch 14 Loss 0.7463
# Time taken for 1 epoch 40.39359521865845 sec
#
# Epoch 15 Batch 0 Loss 0.6649
# Epoch 15 Batch 100 Loss 0.6142
# Epoch 15 Batch 200 Loss 0.6810
# Epoch 15 Batch 300 Loss 0.6965
# Epoch 15 Batch 400 Loss 0.7398
# Epoch 15 Loss 0.6921
# Time taken for 1 epoch 39.60818338394165 sec
#
# Epoch 16 Batch 0 Loss 0.5704
# Epoch 16 Batch 100 Loss 0.5924
# Epoch 16 Batch 200 Loss 0.6190
# Epoch 16 Batch 300 Loss 0.5982
# Epoch 16 Batch 400 Loss 0.6205
# Epoch 16 Loss 0.6425
# Time taken for 1 epoch 40.4518096446991 sec
#
# Epoch 17 Batch 0 Loss 0.5873
# Epoch 17 Batch 100 Loss 0.5920
# Epoch 17 Batch 200 Loss 0.6351
# Epoch 17 Batch 300 Loss 0.4800
# Epoch 17 Batch 400 Loss 0.5947
# Epoch 17 Loss 0.5974
# Time taken for 1 epoch 40.09717655181885 sec
#
# Epoch 18 Batch 0 Loss 0.5747
# Epoch 18 Batch 100 Loss 0.4957
# Epoch 18 Batch 200 Loss 0.5708
# Epoch 18 Batch 300 Loss 0.6155
# Epoch 18 Batch 400 Loss 0.5969
# Epoch 18 Loss 0.5577
# Time taken for 1 epoch 41.72071933746338 sec
#
# Epoch 19 Batch 0 Loss 0.4684
# Epoch 19 Batch 100 Loss 0.5366
# Epoch 19 Batch 200 Loss 0.5532
# Epoch 19 Batch 300 Loss 0.5135
# Epoch 19 Batch 400 Loss 0.4738
# Epoch 19 Loss 0.5170
# Time taken for 1 epoch 39.53644132614136 sec
#
# Epoch 20 Batch 0 Loss 0.5211
# Epoch 20 Batch 100 Loss 0.4530
# Epoch 20 Batch 200 Loss 0.4448
# Epoch 20 Batch 300 Loss 0.5063
# Epoch 20 Batch 400 Loss 0.4417
# Epoch 20 Loss 0.4809
# Time taken for 1 epoch 45.19107103347778 sec
#
# Epoch 21 Batch 0 Loss 0.4320
# Epoch 21 Batch 100 Loss 0.4125
# Epoch 21 Batch 200 Loss 0.4219
# Epoch 21 Batch 300 Loss 0.4723
# Epoch 21 Batch 400 Loss 0.4027
# Epoch 21 Loss 0.4478
# Time taken for 1 epoch 40.01660680770874 sec
#
# Epoch 22 Batch 0 Loss 0.3602
# Epoch 22 Batch 100 Loss 0.3657
# Epoch 22 Batch 200 Loss 0.3785
# Epoch 22 Batch 300 Loss 0.4623
# Epoch 22 Batch 400 Loss 0.4445
# Epoch 22 Loss 0.4195
# Time taken for 1 epoch 40.1182165145874 sec
#
# Epoch 23 Batch 0 Loss 0.3406
# Epoch 23 Batch 100 Loss 0.3323
# Epoch 23 Batch 200 Loss 0.3676
# Epoch 23 Batch 300 Loss 0.4371
# Epoch 23 Batch 400 Loss 0.3649
# Epoch 23 Loss 0.3931
# Time taken for 1 epoch 39.854633808135986 sec
#
# Epoch 24 Batch 0 Loss 0.3019
# Epoch 24 Batch 100 Loss 0.3719
# Epoch 24 Batch 200 Loss 0.3759
# Epoch 24 Batch 300 Loss 0.3788
# Epoch 24 Batch 400 Loss 0.3847
# Epoch 24 Loss 0.3657
# Time taken for 1 epoch 39.976980686187744 sec
#
# Epoch 25 Batch 0 Loss 0.3197
# Epoch 25 Batch 100 Loss 0.2901
# Epoch 25 Batch 200 Loss 0.3347
# Epoch 25 Batch 300 Loss 0.3499
# Epoch 25 Batch 400 Loss 0.3375
# Epoch 25 Loss 0.3392
# Time taken for 1 epoch 39.93069291114807 sec
#
# Epoch 26 Batch 0 Loss 0.2988
# Epoch 26 Batch 100 Loss 0.3204
# Epoch 26 Batch 200 Loss 0.3328
# Epoch 26 Batch 300 Loss 0.2935
# Epoch 26 Batch 400 Loss 0.3217
# Epoch 26 Loss 0.3158
# Time taken for 1 epoch 40.63230848312378 sec
#
# Epoch 27 Batch 0 Loss 0.2661
# Epoch 27 Batch 100 Loss 0.2722
# Epoch 27 Batch 200 Loss 0.2931
# Epoch 27 Batch 300 Loss 0.3368
# Epoch 27 Batch 400 Loss 0.2595
# Epoch 27 Loss 0.2965
# Time taken for 1 epoch 39.921379804611206 sec
#
# Epoch 28 Batch 0 Loss 0.2400
# Epoch 28 Batch 100 Loss 0.2745
# Epoch 28 Batch 200 Loss 0.2572
# Epoch 28 Batch 300 Loss 0.2315
# Epoch 28 Batch 400 Loss 0.3583
# Epoch 28 Loss 0.2762
# Time taken for 1 epoch 42.90075492858887 sec
#
# Epoch 29 Batch 0 Loss 0.3017
# Epoch 29 Batch 100 Loss 0.2225
# Epoch 29 Batch 200 Loss 0.2507
# Epoch 29 Batch 300 Loss 0.2674
# Epoch 29 Batch 400 Loss 0.2458
# Epoch 29 Loss 0.2568
# Time taken for 1 epoch 42.47954726219177 sec
#
# Epoch 30 Batch 0 Loss 0.2237
# Epoch 30 Batch 100 Loss 0.1872
# Epoch 30 Batch 200 Loss 0.2914
# Epoch 30 Batch 300 Loss 0.2572
# Epoch 30 Batch 400 Loss 0.2542
# Epoch 30 Loss 0.2406
# Time taken for 1 epoch 44.8648738861084 sec
#
# Epoch 31 Batch 0 Loss 0.1970
# Epoch 31 Batch 100 Loss 0.1924
# Epoch 31 Batch 200 Loss 0.2455
# Epoch 31 Batch 300 Loss 0.2943
# Epoch 31 Batch 400 Loss 0.2256
# Epoch 31 Loss 0.2273
# Time taken for 1 epoch 39.6687114238739 sec
#
# Epoch 32 Batch 0 Loss 0.1617
# Epoch 32 Batch 100 Loss 0.1802
# Epoch 32 Batch 200 Loss 0.1919
# Epoch 32 Batch 300 Loss 0.1812
# Epoch 32 Batch 400 Loss 0.2358
# Epoch 32 Loss 0.2122
# Time taken for 1 epoch 45.33650040626526 sec
#
# Epoch 33 Batch 0 Loss 0.2074
# Epoch 33 Batch 100 Loss 0.1895
# Epoch 33 Batch 200 Loss 0.1830
# Epoch 33 Batch 300 Loss 0.2205
# Epoch 33 Batch 400 Loss 0.1957
# Epoch 33 Loss 0.1981
# Time taken for 1 epoch 39.68544387817383 sec
#
# Epoch 34 Batch 0 Loss 0.1573
# Epoch 34 Batch 100 Loss 0.1544
# Epoch 34 Batch 200 Loss 0.2019
# Epoch 34 Batch 300 Loss 0.1789
# Epoch 34 Batch 400 Loss 0.2013
# Epoch 34 Loss 0.1838
# Time taken for 1 epoch 45.245039224624634 sec
#
# Epoch 35 Batch 0 Loss 0.1600
# Epoch 35 Batch 100 Loss 0.1484
# Epoch 35 Batch 200 Loss 0.1512
# Epoch 35 Batch 300 Loss 0.1998
# Epoch 35 Batch 400 Loss 0.1823
# Epoch 35 Loss 0.1743
# Time taken for 1 epoch 39.94467067718506 sec
#
# Epoch 36 Batch 0 Loss 0.1180
# Epoch 36 Batch 100 Loss 0.1619
# Epoch 36 Batch 200 Loss 0.1499
# Epoch 36 Batch 300 Loss 0.1624
# Epoch 36 Batch 400 Loss 0.1716
# Epoch 36 Loss 0.1622
# Time taken for 1 epoch 40.515594720840454 sec
#
# Epoch 37 Batch 0 Loss 0.1171
# Epoch 37 Batch 100 Loss 0.1487
# Epoch 37 Batch 200 Loss 0.1536
# Epoch 37 Batch 300 Loss 0.1487
# Epoch 37 Batch 400 Loss 0.1751
# Epoch 37 Loss 0.1593
# Time taken for 1 epoch 40.0887656211853 sec
#
# Epoch 38 Batch 0 Loss 0.1656
# Epoch 38 Batch 100 Loss 0.1168
# Epoch 38 Batch 200 Loss 0.1422
# Epoch 38 Batch 300 Loss 0.1438
# Epoch 38 Batch 400 Loss 0.1639
# Epoch 38 Loss 0.1465
# Time taken for 1 epoch 41.835047245025635 sec
#
# Epoch 39 Batch 0 Loss 0.1364
# Epoch 39 Batch 100 Loss 0.1426
# Epoch 39 Batch 200 Loss 0.1179
# Epoch 39 Batch 300 Loss 0.1064
# Epoch 39 Batch 400 Loss 0.1294
# Epoch 39 Loss 0.1316
# Time taken for 1 epoch 39.64676880836487 sec
#
# Epoch 40 Batch 0 Loss 0.1011
# Epoch 40 Batch 100 Loss 0.1481
# Epoch 40 Batch 200 Loss 0.1401
# Epoch 40 Batch 300 Loss 0.1282
# Epoch 40 Batch 400 Loss 0.1066
# Epoch 40 Loss 0.1232
# Time taken for 1 epoch 45.53081798553467 sec
#
# Epoch 41 Batch 0 Loss 0.1072
# Epoch 41 Batch 100 Loss 0.1098
# Epoch 41 Batch 200 Loss 0.1132
# Epoch 41 Batch 300 Loss 0.1289
# Epoch 41 Batch 400 Loss 0.1304
# Epoch 41 Loss 0.1161
# Time taken for 1 epoch 39.674092054367065 sec
#
# Epoch 42 Batch 0 Loss 0.1317
# Epoch 42 Batch 100 Loss 0.1238
# Epoch 42 Batch 200 Loss 0.0957
# Epoch 42 Batch 300 Loss 0.1196
# Epoch 42 Batch 400 Loss 0.1397
# Epoch 42 Loss 0.1193
# Time taken for 1 epoch 43.697656869888306 sec
#
# Epoch 43 Batch 0 Loss 0.0994
# Epoch 43 Batch 100 Loss 0.1057
# Epoch 43 Batch 200 Loss 0.0718
# Epoch 43 Batch 300 Loss 0.0897
# Epoch 43 Batch 400 Loss 0.1119
# Epoch 43 Loss 0.1070
# Time taken for 1 epoch 39.85237193107605 sec
#
# Epoch 44 Batch 0 Loss 0.1081
# Epoch 44 Batch 100 Loss 0.1061
# Epoch 44 Batch 200 Loss 0.1182
# Epoch 44 Batch 300 Loss 0.1341
# Epoch 44 Batch 400 Loss 0.0973
# Epoch 44 Loss 0.0981
# Time taken for 1 epoch 45.31060814857483 sec
#
# Epoch 45 Batch 0 Loss 0.0689
# Epoch 45 Batch 100 Loss 0.1011
# Epoch 45 Batch 200 Loss 0.0847
# Epoch 45 Batch 300 Loss 0.0776
# Epoch 45 Batch 400 Loss 0.1191
# Epoch 45 Loss 0.0906
# Time taken for 1 epoch 39.70362901687622 sec
#
# Epoch 46 Batch 0 Loss 0.0718
# Epoch 46 Batch 100 Loss 0.1143
# Epoch 46 Batch 200 Loss 0.0902
# Epoch 46 Batch 300 Loss 0.0799
# Epoch 46 Batch 400 Loss 0.0906
# Epoch 46 Loss 0.0887
# Time taken for 1 epoch 43.477768421173096 sec
#
# Epoch 47 Batch 0 Loss 0.0678
# Epoch 47 Batch 100 Loss 0.0807
# Epoch 47 Batch 200 Loss 0.0698
# Epoch 47 Batch 300 Loss 0.0722
# Epoch 47 Batch 400 Loss 0.0883
# Epoch 47 Loss 0.0834
# Time taken for 1 epoch 39.92946815490723 sec
#
# Epoch 48 Batch 0 Loss 0.0711
# Epoch 48 Batch 100 Loss 0.0641
# Epoch 48 Batch 200 Loss 0.0870
# Epoch 48 Batch 300 Loss 0.0994
# Epoch 48 Batch 400 Loss 0.0690
# Epoch 48 Loss 0.0778
# Time taken for 1 epoch 40.07285451889038 sec
#
# Epoch 49 Batch 0 Loss 0.0558
# Epoch 49 Batch 100 Loss 0.0560
# Epoch 49 Batch 200 Loss 0.0705
# Epoch 49 Batch 300 Loss 0.0692
# Epoch 49 Batch 400 Loss 0.0970
# Epoch 49 Loss 0.0762
# Time taken for 1 epoch 39.61109662055969 sec
#
# Epoch 50 Batch 0 Loss 0.0823
# Epoch 50 Batch 100 Loss 0.1011
# Epoch 50 Batch 200 Loss 0.0516
# Epoch 50 Batch 300 Loss 0.0920
# Epoch 50 Batch 400 Loss 0.0963
# Epoch 50 Loss 0.0746
# Time taken for 1 epoch 45.274933099746704 sec
#
# Epoch 51 Batch 0 Loss 0.0607
# Epoch 51 Batch 100 Loss 0.0907
# Epoch 51 Batch 200 Loss 0.0792
# Epoch 51 Batch 300 Loss 0.0661
# Epoch 51 Batch 400 Loss 0.0791
# Epoch 51 Loss 0.0675
# Time taken for 1 epoch 40.26223564147949 sec
#
# Epoch 52 Batch 0 Loss 0.0390
# Epoch 52 Batch 100 Loss 0.0451
# Epoch 52 Batch 200 Loss 0.0699
# Epoch 52 Batch 300 Loss 0.0744
# Epoch 52 Batch 400 Loss 0.1005
# Epoch 52 Loss 0.0607
# Time taken for 1 epoch 40.2318856716156 sec
#
# Epoch 53 Batch 0 Loss 0.0448
# Epoch 53 Batch 100 Loss 0.0877
# Epoch 53 Batch 200 Loss 0.0559
# Epoch 53 Batch 300 Loss 0.0484
# Epoch 53 Batch 400 Loss 0.0683
# Epoch 53 Loss 0.0630
# Time taken for 1 epoch 39.52250099182129 sec
#
# Epoch 54 Batch 0 Loss 0.0571
# Epoch 54 Batch 100 Loss 0.0738
# Epoch 54 Batch 200 Loss 0.0738
# Epoch 54 Batch 300 Loss 0.0563
# Epoch 54 Batch 400 Loss 0.0759
# Epoch 54 Loss 0.0659
# Time taken for 1 epoch 43.36082172393799 sec
#
# Epoch 55 Batch 0 Loss 0.0495
# Epoch 55 Batch 100 Loss 0.0589
# Epoch 55 Batch 200 Loss 0.0598
# Epoch 55 Batch 300 Loss 0.0595
# Epoch 55 Batch 400 Loss 0.0660
# Epoch 55 Loss 0.0643
# Time taken for 1 epoch 39.67351269721985 sec
#
# Epoch 56 Batch 0 Loss 0.0378
# Epoch 56 Batch 100 Loss 0.0548
# Epoch 56 Batch 200 Loss 0.0374
# Epoch 56 Batch 300 Loss 0.0497
# Epoch 56 Batch 400 Loss 0.0536
# Epoch 56 Loss 0.0555
# Time taken for 1 epoch 44.932480573654175 sec
#
# Epoch 57 Batch 0 Loss 0.0313
# Epoch 57 Batch 100 Loss 0.0441
# Epoch 57 Batch 200 Loss 0.0513
# Epoch 57 Batch 300 Loss 0.0582
# Epoch 57 Batch 400 Loss 0.0599
# Epoch 57 Loss 0.0455
# Time taken for 1 epoch 39.825655460357666 sec
#
# Epoch 58 Batch 0 Loss 0.0301
# Epoch 58 Batch 100 Loss 0.0341
# Epoch 58 Batch 200 Loss 0.0384
# Epoch 58 Batch 300 Loss 0.0478
# Epoch 58 Batch 400 Loss 0.0369
# Epoch 58 Loss 0.0411
# Time taken for 1 epoch 42.51885437965393 sec
#
# Epoch 59 Batch 0 Loss 0.0369
# Epoch 59 Batch 100 Loss 0.0397
# Epoch 59 Batch 200 Loss 0.0406
# Epoch 59 Batch 300 Loss 0.0413
# Epoch 59 Batch 400 Loss 0.0467
# Epoch 59 Loss 0.0393
# Time taken for 1 epoch 40.0387659072876 sec
#
# Epoch 60 Batch 0 Loss 0.0367
# Epoch 60 Batch 100 Loss 0.0529
# Epoch 60 Batch 200 Loss 0.0691
# Epoch 60 Batch 300 Loss 0.0438
# Epoch 60 Batch 400 Loss 0.0719
# Epoch 60 Loss 0.0552
# Time taken for 1 epoch 42.92299437522888 sec
#
# Epoch 61 Batch 0 Loss 0.0479
# Epoch 61 Batch 100 Loss 0.0550
# Epoch 61 Batch 200 Loss 0.0686
# Epoch 61 Batch 300 Loss 0.0499
# Epoch 61 Batch 400 Loss 0.0567
# Epoch 61 Loss 0.0551
# Time taken for 1 epoch 39.64102077484131 sec
#
# Epoch 62 Batch 0 Loss 0.0623
# Epoch 62 Batch 100 Loss 0.0475
# Epoch 62 Batch 200 Loss 0.0350
# Epoch 62 Batch 300 Loss 0.0516
# Epoch 62 Batch 400 Loss 0.0529
# Epoch 62 Loss 0.0535
# Time taken for 1 epoch 40.08962106704712 sec
#
# Epoch 63 Batch 0 Loss 0.0312
# Epoch 63 Batch 100 Loss 0.0369
# Epoch 63 Batch 200 Loss 0.0423
# Epoch 63 Batch 300 Loss 0.0333
# Epoch 63 Batch 400 Loss 0.0518
# Epoch 63 Loss 0.0393
# Time taken for 1 epoch 39.5697135925293 sec
#
# Epoch 64 Batch 0 Loss 0.0317
# Epoch 64 Batch 100 Loss 0.0372
# Epoch 64 Batch 200 Loss 0.0354
# Epoch 64 Batch 300 Loss 0.0446
# Epoch 64 Batch 400 Loss 0.0296
# Epoch 64 Loss 0.0349
# Time taken for 1 epoch 40.079538106918335 sec
#
# Epoch 65 Batch 0 Loss 0.0263
# Epoch 65 Batch 100 Loss 0.0312
# Epoch 65 Batch 200 Loss 0.0310
# Epoch 65 Batch 300 Loss 0.0408
# Epoch 65 Batch 400 Loss 0.0256
# Epoch 65 Loss 0.0324
# Time taken for 1 epoch 39.63898181915283 sec
#
# Epoch 66 Batch 0 Loss 0.0278
# Epoch 66 Batch 100 Loss 0.0276
# Epoch 66 Batch 200 Loss 0.0205
# Epoch 66 Batch 300 Loss 0.0741
# Epoch 66 Batch 400 Loss 0.0610
# Epoch 66 Loss 0.0432
# Time taken for 1 epoch 43.128472328186035 sec
#
# Epoch 67 Batch 0 Loss 0.0376
# Epoch 67 Batch 100 Loss 0.0264
# Epoch 67 Batch 200 Loss 0.0517
# Epoch 67 Batch 300 Loss 0.0475
# Epoch 67 Batch 400 Loss 0.0527
# Epoch 67 Loss 0.0424
# Time taken for 1 epoch 39.66834616661072 sec
#
# Epoch 68 Batch 0 Loss 0.0322
# Epoch 68 Batch 100 Loss 0.0288
# Epoch 68 Batch 200 Loss 0.0333
# Epoch 68 Batch 300 Loss 0.0355
# Epoch 68 Batch 400 Loss 0.0360
# Epoch 68 Loss 0.0317
# Time taken for 1 epoch 44.73185896873474 sec
#
# Epoch 69 Batch 0 Loss 0.0197
# Epoch 69 Batch 100 Loss 0.0279
# Epoch 69 Batch 200 Loss 0.0275
# Epoch 69 Batch 300 Loss 0.0349
# Epoch 69 Batch 400 Loss 0.0297
# Epoch 69 Loss 0.0264
# Time taken for 1 epoch 42.40923357009888 sec
#
# Epoch 70 Batch 0 Loss 0.0240
# Epoch 70 Batch 100 Loss 0.0252
# Epoch 70 Batch 200 Loss 0.0155
# Epoch 70 Batch 300 Loss 0.0215
# Epoch 70 Batch 400 Loss 0.0512
# Epoch 70 Loss 0.0291
# Time taken for 1 epoch 40.93781304359436 sec
#
# Epoch 71 Batch 0 Loss 0.0380
# Epoch 71 Batch 100 Loss 0.0356
# Epoch 71 Batch 200 Loss 0.0341
# Epoch 71 Batch 300 Loss 0.0431
# Epoch 71 Batch 400 Loss 0.0404
# Epoch 71 Loss 0.0403
# Time taken for 1 epoch 39.60502219200134 sec
#
# Epoch 72 Batch 0 Loss 0.0286
# Epoch 72 Batch 100 Loss 0.0262
# Epoch 72 Batch 200 Loss 0.0347
# Epoch 72 Batch 300 Loss 0.0411
# Epoch 72 Batch 400 Loss 0.0374
# Epoch 72 Loss 0.0327
# Time taken for 1 epoch 42.500465869903564 sec
#
# Epoch 73 Batch 0 Loss 0.0326
# Epoch 73 Batch 100 Loss 0.0227
# Epoch 73 Batch 200 Loss 0.0273
# Epoch 73 Batch 300 Loss 0.0327
# Epoch 73 Batch 400 Loss 0.0434
# Epoch 73 Loss 0.0296
# Time taken for 1 epoch 40.1548011302948 sec
#
# Epoch 74 Batch 0 Loss 0.0199
# Epoch 74 Batch 100 Loss 0.0317
# Epoch 74 Batch 200 Loss 0.0315
# Epoch 74 Batch 300 Loss 0.0241
# Epoch 74 Batch 400 Loss 0.0419
# Epoch 74 Loss 0.0256
# Time taken for 1 epoch 43.3293731212616 sec
#
# Epoch 75 Batch 0 Loss 0.0196
# Epoch 75 Batch 100 Loss 0.0236
# Epoch 75 Batch 200 Loss 0.0224
# Epoch 75 Batch 300 Loss 0.0322
# Epoch 75 Batch 400 Loss 0.0415
# Epoch 75 Loss 0.0270
# Time taken for 1 epoch 39.58329796791077 sec
#
# Epoch 76 Batch 0 Loss 0.0184
# Epoch 76 Batch 100 Loss 0.0308
# Epoch 76 Batch 200 Loss 0.0504
# Epoch 76 Batch 300 Loss 0.0245
# Epoch 76 Batch 400 Loss 0.0289
# Epoch 76 Loss 0.0308
# Time taken for 1 epoch 43.33232498168945 sec
#
# Epoch 77 Batch 0 Loss 0.0311
# Epoch 77 Batch 100 Loss 0.0305
# Epoch 77 Batch 200 Loss 0.0210
# Epoch 77 Batch 300 Loss 0.0274
# Epoch 77 Batch 400 Loss 0.0314
# Epoch 77 Loss 0.0335
# Time taken for 1 epoch 39.70716881752014 sec
#
# Epoch 78 Batch 0 Loss 0.0288
# Epoch 78 Batch 100 Loss 0.0213
# Epoch 78 Batch 200 Loss 0.0328
# Epoch 78 Batch 300 Loss 0.0311
# Epoch 78 Batch 400 Loss 0.0300
# Epoch 78 Loss 0.0338
# Time taken for 1 epoch 43.62844252586365 sec
#
# Epoch 79 Batch 0 Loss 0.0227
# Epoch 79 Batch 100 Loss 0.0132
# Epoch 79 Batch 200 Loss 0.0231
# Epoch 79 Batch 300 Loss 0.0140
# Epoch 79 Batch 400 Loss 0.0205
# Epoch 79 Loss 0.0241
# Time taken for 1 epoch 39.67512631416321 sec
#
# Epoch 80 Batch 0 Loss 0.0189
# Epoch 80 Batch 100 Loss 0.0202
# Epoch 80 Batch 200 Loss 0.0210
# Epoch 80 Batch 300 Loss 0.0270
# Epoch 80 Batch 400 Loss 0.0226
# Epoch 80 Loss 0.0232
# Time taken for 1 epoch 42.89143085479736 sec
#
# Epoch 81 Batch 0 Loss 0.0166
# Epoch 81 Batch 100 Loss 0.0170
# Epoch 81 Batch 200 Loss 0.0209
# Epoch 81 Batch 300 Loss 0.0133
# Epoch 81 Batch 400 Loss 0.0208
# Epoch 81 Loss 0.0182
# Time taken for 1 epoch 39.73987579345703 sec
#
# Epoch 82 Batch 0 Loss 0.0170
# Epoch 82 Batch 100 Loss 0.0149
# Epoch 82 Batch 200 Loss 0.0127
# Epoch 82 Batch 300 Loss 0.0160
# Epoch 82 Batch 400 Loss 0.0202
# Epoch 82 Loss 0.0147
# Time taken for 1 epoch 43.22293138504028 sec
#
# Epoch 83 Batch 0 Loss 0.0078
# Epoch 83 Batch 100 Loss 0.0103
# Epoch 83 Batch 200 Loss 0.0153
# Epoch 83 Batch 300 Loss 0.0163
# Epoch 83 Batch 400 Loss 0.0171
# Epoch 83 Loss 0.0164
# Time taken for 1 epoch 39.72271108627319 sec
#
# Epoch 84 Batch 0 Loss 0.0139
# Epoch 84 Batch 100 Loss 0.0312
# Epoch 84 Batch 200 Loss 0.0289
# Epoch 84 Batch 300 Loss 0.0393
# Epoch 84 Batch 400 Loss 0.0334
# Epoch 84 Loss 0.0323
# Time taken for 1 epoch 43.20449757575989 sec
#
# Epoch 85 Batch 0 Loss 0.0376
# Epoch 85 Batch 100 Loss 0.0501
# Epoch 85 Batch 200 Loss 0.0326
# Epoch 85 Batch 300 Loss 0.0309
# Epoch 85 Batch 400 Loss 0.0356
# Epoch 85 Loss 0.0394
# Time taken for 1 epoch 40.00846600532532 sec
#
# Epoch 86 Batch 0 Loss 0.0434
# Epoch 86 Batch 100 Loss 0.0302
# Epoch 86 Batch 200 Loss 0.0162
# Epoch 86 Batch 300 Loss 0.0324
# Epoch 86 Batch 400 Loss 0.0200
# Epoch 86 Loss 0.0256
# Time taken for 1 epoch 41.649131059646606 sec
#
# Epoch 87 Batch 0 Loss 0.0143
# Epoch 87 Batch 100 Loss 0.0182
# Epoch 87 Batch 200 Loss 0.0149
# Epoch 87 Batch 300 Loss 0.0161
# Epoch 87 Batch 400 Loss 0.0143
# Epoch 87 Loss 0.0179
# Time taken for 1 epoch 39.63284873962402 sec
#
# Epoch 88 Batch 0 Loss 0.0150
# Epoch 88 Batch 100 Loss 0.0128
# Epoch 88 Batch 200 Loss 0.0143
# Epoch 88 Batch 300 Loss 0.0108
# Epoch 88 Batch 400 Loss 0.0096
# Epoch 88 Loss 0.0125
# Time taken for 1 epoch 42.496766567230225 sec
#
# Epoch 89 Batch 0 Loss 0.0079
# Epoch 89 Batch 100 Loss 0.0088
# Epoch 89 Batch 200 Loss 0.0039
# Epoch 89 Batch 300 Loss 0.0099
# Epoch 89 Batch 400 Loss 0.0079
# Epoch 89 Loss 0.0102
# Time taken for 1 epoch 39.637473344802856 sec
#
# Epoch 90 Batch 0 Loss 0.0198
# Epoch 90 Batch 100 Loss 0.0120
# Epoch 90 Batch 200 Loss 0.0103
# Epoch 90 Batch 300 Loss 0.0206
# Epoch 90 Batch 400 Loss 0.0194
# Epoch 90 Loss 0.0173
# Time taken for 1 epoch 43.88488578796387 sec
#
# Epoch 91 Batch 0 Loss 0.0266
# Epoch 91 Batch 100 Loss 0.0265
# Epoch 91 Batch 200 Loss 0.0252
# Epoch 91 Batch 300 Loss 0.0434
# Epoch 91 Batch 400 Loss 0.0426
# Epoch 91 Loss 0.0327
# Time taken for 1 epoch 39.68462371826172 sec
#
# Epoch 92 Batch 0 Loss 0.0438
# Epoch 92 Batch 100 Loss 0.0208
# Epoch 92 Batch 200 Loss 0.0413
# Epoch 92 Batch 300 Loss 0.0349
# Epoch 92 Batch 400 Loss 0.0419
# Epoch 92 Loss 0.0363
# Time taken for 1 epoch 45.3872127532959 sec
#
# Epoch 93 Batch 0 Loss 0.0303
# Epoch 93 Batch 100 Loss 0.0301
# Epoch 93 Batch 200 Loss 0.0294
# Epoch 93 Batch 300 Loss 0.0387
# Epoch 93 Batch 400 Loss 0.0426
# Epoch 93 Loss 0.0313
# Time taken for 1 epoch 39.602234840393066 sec
#
# Epoch 94 Batch 0 Loss 0.0184
# Epoch 94 Batch 100 Loss 0.0301
# Epoch 94 Batch 200 Loss 0.0178
# Epoch 94 Batch 300 Loss 0.0190
# Epoch 94 Batch 400 Loss 0.0212
# Epoch 94 Loss 0.0179
# Time taken for 1 epoch 40.55682969093323 sec
#
# Epoch 95 Batch 0 Loss 0.0153
# Epoch 95 Batch 100 Loss 0.0062
# Epoch 95 Batch 200 Loss 0.0102
# Epoch 95 Batch 300 Loss 0.0086
# Epoch 95 Batch 400 Loss 0.0119
# Epoch 95 Loss 0.0125
# Time taken for 1 epoch 39.55458688735962 sec
#
# Epoch 96 Batch 0 Loss 0.0077
# Epoch 96 Batch 100 Loss 0.0051
# Epoch 96 Batch 200 Loss 0.0064
# Epoch 96 Batch 300 Loss 0.0085
# Epoch 96 Batch 400 Loss 0.0129
# Epoch 96 Loss 0.0101
# Time taken for 1 epoch 43.36754012107849 sec
#
# Epoch 97 Batch 0 Loss 0.0045
# Epoch 97 Batch 100 Loss 0.0058
# Epoch 97 Batch 200 Loss 0.0040
# Epoch 97 Batch 300 Loss 0.0098
# Epoch 97 Batch 400 Loss 0.0123
# Epoch 97 Loss 0.0080
# Time taken for 1 epoch 39.630380392074585 sec
#
# Epoch 98 Batch 0 Loss 0.0085
# Epoch 98 Batch 100 Loss 0.0141
# Epoch 98 Batch 200 Loss 0.0064
# Epoch 98 Batch 300 Loss 0.0064
# Epoch 98 Batch 400 Loss 0.0122
# Epoch 98 Loss 0.0100
# Time taken for 1 epoch 42.95606756210327 sec
#
# Epoch 99 Batch 0 Loss 0.0314
# Epoch 99 Batch 100 Loss 0.0242
# Epoch 99 Batch 200 Loss 0.0299
# Epoch 99 Batch 300 Loss 0.0215
# Epoch 99 Batch 400 Loss 0.0400
# Epoch 99 Loss 0.0304
# Time taken for 1 epoch 39.70038390159607 sec
#
# Epoch 100 Batch 0 Loss 0.0392
# Epoch 100 Batch 100 Loss 0.0355
# Epoch 100 Batch 200 Loss 0.0387
# Epoch 100 Batch 300 Loss 0.0351
# Epoch 100 Batch 400 Loss 0.0479
# Epoch 100 Loss 0.0383
# Time taken for 1 epoch 45.34748649597168 sec

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))
    sentence = preprocess_sentence(sentence)
    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_length_inp,
                                                           padding='post')
    inputs = tf.convert_to_tensor(inputs)
    result = ''
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)
    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                             dec_hidden,
                                                             enc_out)
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += targ_lang.index_word[predicted_id] + ' '
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence
        dec_input = tf.expand_dims([predicted_id], 0)
    return result, sentence

# %%
def translate(sentence):
    result, sentence = evaluate(sentence)
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))
    return result
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
import numpy as np
result=translate(u'Definitely share your feedback in the comment section.')

# %%
import numpy as np
result=translate(u'So even if its a big video, I will clearly mention all the products')

# %%
import numpy as np
result=translate(u'I was waiting for my bag.')
